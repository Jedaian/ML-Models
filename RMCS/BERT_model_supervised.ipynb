# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 78.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import DistilBertTokenizerFast, DistilBertForSequenceClassification, AdamW
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-4-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# ##Pre-processing Data

# %%
#Biased data
data = pd.read_csv('/content/drive/MyDrive/BERT Models/Dataset/mergedData.csv')
data.drop_duplicates(subset = ['sentence'], inplace = True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3141 entries, 0 to 3140
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentence  3141 non-null   object
#  1   label     3141 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 73.6+ KB

# %%
#Unbiased data
data2 = pd.read_csv('/content/drive/MyDrive/BERT Models/Dataset/unbiasedDataTrain.csv')
data2['sentence'].nunique()
lengths = data2['sentence'].str.len()
argmax = np.where(lengths == lengths.max())[0]
data2['sentence'].iloc[argmax]
# data2.sort_values('sentence',key=lambda x:x.str.len())
# Out:
# 250    I just left the most cringeworthy voicemail to...
# Name: sentence, dtype: object

# %%
lengths = data['sentence'].str.len()
argmax = np.where(lengths == lengths.max())[0]
data.iloc[argmax]
# Out:
#                                                sentence  label
# 2019  I think the culture (and laws) about it are di...      0

# %%
#custom dataset for supervised learning
class SlangDataset(Dataset):
  def __init__(self, filename, tokenizer):
    df = filename
    self.data = list(zip(df['sentence'], df['label']))
    self.tokenizer = tokenizer

  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    text, label = self.data[idx]
    inputs = self.tokenizer(text, padding='max_length', truncation=True, max_length=128, return_tensors='pt')
    inputs['input_ids'] = inputs['input_ids'].squeeze()
    inputs['attention_mask'] = inputs['attention_mask'].squeeze()
    return {
        'inputs': inputs,
        'label': torch.tensor(label, dtype=torch.long)
    }

model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=2) # 2 labels: Slang, No Slang
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)

dataset = data2

#encoding the dataset for training
slang_dataset = SlangDataset(dataset, tokenizer)
dataloader = DataLoader(slang_dataset, batch_size=16, shuffle=True)

optimizer = AdamW(model.parameters(), lr=1e-5)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.bias', 'pre_classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
n = 100
model.train()
loss_values = []
for epoch in tqdm(range(n), desc = 'Epochs'):
  epoch_loss = 0.0
  for i, batch in enumerate(tqdm(dataloader, desc = f'Batch (Epoch{epoch+1})')):
    input_ids = batch['inputs']['input_ids'].to(device)
    attention_mask = batch['inputs']['attention_mask'].to(device)
    labels = batch['label'].to(device)
    outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
    loss = outputs.loss
    epoch_loss += loss.item()
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
  epoch_loss = epoch_loss/len(dataloader)
  loss_values.append(epoch_loss)
# Out:
# Batch (Epoch81):  64%|██████▍   | 32/50 [00:05<00:02,  6.09it/s]
# Batch (Epoch81):  66%|██████▌   | 33/50 [00:05<00:02,  6.08it/s]
# Batch (Epoch81):  68%|██████▊   | 34/50 [00:05<00:02,  6.05it/s]
# Batch (Epoch81):  70%|███████   | 35/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch81):  72%|███████▏  | 36/50 [00:05<00:02,  5.99it/s]
# Batch (Epoch81):  74%|███████▍  | 37/50 [00:06<00:02,  6.07it/s]
# Batch (Epoch81):  76%|███████▌  | 38/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch81):  78%|███████▊  | 39/50 [00:06<00:01,  6.10it/s]
# Batch (Epoch81):  80%|████████  | 40/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch81):  82%|████████▏ | 41/50 [00:06<00:01,  6.02it/s]
# Batch (Epoch81):  84%|████████▍ | 42/50 [00:06<00:01,  6.03it/s]
# Batch (Epoch81):  86%|████████▌ | 43/50 [00:07<00:01,  6.04it/s]
# Batch (Epoch81):  88%|████████▊ | 44/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch81):  90%|█████████ | 45/50 [00:07<00:00,  6.03it/s]
# Batch (Epoch81):  92%|█████████▏| 46/50 [00:07<00:00,  6.12it/s]
# Batch (Epoch81):  94%|█████████▍| 47/50 [00:07<00:00,  6.07it/s]
# Batch (Epoch81):  96%|█████████▌| 48/50 [00:07<00:00,  6.05it/s]
# Batch (Epoch81):  98%|█████████▊| 49/50 [00:08<00:00,  6.03it/s]
# Batch (Epoch81): 100%|██████████| 50/50 [00:08<00:00,  6.05it/s]
# Epochs:  81%|████████  | 81/100 [11:04<02:36,  8.26s/it]
# Batch (Epoch82):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch82):   2%|▏         | 1/50 [00:00<00:06,  7.07it/s]
# Batch (Epoch82):   4%|▍         | 2/50 [00:00<00:07,  6.27it/s]
# Batch (Epoch82):   6%|▌         | 3/50 [00:00<00:07,  6.42it/s]
# Batch (Epoch82):   8%|▊         | 4/50 [00:00<00:07,  6.30it/s]
# Batch (Epoch82):  10%|█         | 5/50 [00:00<00:07,  6.21it/s]
# Batch (Epoch82):  12%|█▏        | 6/50 [00:00<00:07,  6.14it/s]
# Batch (Epoch82):  14%|█▍        | 7/50 [00:01<00:07,  6.09it/s]
# Batch (Epoch82):  16%|█▌        | 8/50 [00:01<00:06,  6.10it/s]
# Batch (Epoch82):  18%|█▊        | 9/50 [00:01<00:06,  6.08it/s]
# Batch (Epoch82):  20%|██        | 10/50 [00:01<00:06,  6.10it/s]
# Batch (Epoch82):  22%|██▏       | 11/50 [00:01<00:06,  6.10it/s]
# Batch (Epoch82):  24%|██▍       | 12/50 [00:01<00:06,  6.09it/s]
# Batch (Epoch82):  26%|██▌       | 13/50 [00:02<00:06,  6.05it/s]
# Batch (Epoch82):  28%|██▊       | 14/50 [00:02<00:05,  6.04it/s]
# Batch (Epoch82):  30%|███       | 15/50 [00:02<00:05,  6.03it/s]
# Batch (Epoch82):  32%|███▏      | 16/50 [00:02<00:05,  6.05it/s]
# Batch (Epoch82):  34%|███▍      | 17/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch82):  36%|███▌      | 18/50 [00:02<00:05,  6.09it/s]
# Batch (Epoch82):  38%|███▊      | 19/50 [00:03<00:05,  6.09it/s]
# Batch (Epoch82):  40%|████      | 20/50 [00:03<00:04,  6.07it/s]
# Batch (Epoch82):  42%|████▏     | 21/50 [00:03<00:04,  6.03it/s]
# Batch (Epoch82):  44%|████▍     | 22/50 [00:03<00:04,  6.03it/s]
# Batch (Epoch82):  46%|████▌     | 23/50 [00:03<00:04,  6.04it/s]
# Batch (Epoch82):  48%|████▊     | 24/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch82):  50%|█████     | 25/50 [00:04<00:04,  6.07it/s]
# Batch (Epoch82):  52%|█████▏    | 26/50 [00:04<00:03,  6.06it/s]
# Batch (Epoch82):  54%|█████▍    | 27/50 [00:04<00:03,  6.00it/s]
# Batch (Epoch82):  56%|█████▌    | 28/50 [00:04<00:03,  5.95it/s]
# Batch (Epoch82):  58%|█████▊    | 29/50 [00:04<00:03,  5.92it/s]
# Batch (Epoch82):  60%|██████    | 30/50 [00:04<00:03,  6.02it/s]
# Batch (Epoch82):  62%|██████▏   | 31/50 [00:05<00:03,  5.92it/s]
# Batch (Epoch82):  64%|██████▍   | 32/50 [00:05<00:02,  6.09it/s]
# Batch (Epoch82):  66%|██████▌   | 33/50 [00:05<00:02,  5.82it/s]
# Batch (Epoch82):  68%|██████▊   | 34/50 [00:05<00:02,  6.09it/s]
# Batch (Epoch82):  70%|███████   | 35/50 [00:05<00:02,  5.93it/s]
# Batch (Epoch82):  72%|███████▏  | 36/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch82):  74%|███████▍  | 37/50 [00:06<00:02,  5.95it/s]
# Batch (Epoch82):  76%|███████▌  | 38/50 [00:06<00:02,  5.93it/s]
# Batch (Epoch82):  78%|███████▊  | 39/50 [00:06<00:01,  5.98it/s]
# Batch (Epoch82):  80%|████████  | 40/50 [00:06<00:01,  6.14it/s]
# Batch (Epoch82):  82%|████████▏ | 41/50 [00:06<00:01,  5.96it/s]
# Batch (Epoch82):  84%|████████▍ | 42/50 [00:06<00:01,  6.11it/s]
# Batch (Epoch82):  86%|████████▌ | 43/50 [00:07<00:01,  5.99it/s]
# Batch (Epoch82):  88%|████████▊ | 44/50 [00:07<00:00,  6.02it/s]
# Batch (Epoch82):  90%|█████████ | 45/50 [00:07<00:00,  6.02it/s]
# Batch (Epoch82):  92%|█████████▏| 46/50 [00:07<00:00,  5.98it/s]
# Batch (Epoch82):  94%|█████████▍| 47/50 [00:07<00:00,  5.95it/s]
# Batch (Epoch82):  96%|█████████▌| 48/50 [00:07<00:00,  6.07it/s]
# Batch (Epoch82):  98%|█████████▊| 49/50 [00:08<00:00,  6.08it/s]
# Batch (Epoch82): 100%|██████████| 50/50 [00:08<00:00,  6.04it/s]
# Epochs:  82%|████████▏ | 82/100 [11:12<02:28,  8.26s/it]
# Batch (Epoch83):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch83):   2%|▏         | 1/50 [00:00<00:07,  6.38it/s]
# Batch (Epoch83):   4%|▍         | 2/50 [00:00<00:07,  6.18it/s]
# Batch (Epoch83):   6%|▌         | 3/50 [00:00<00:07,  5.97it/s]
# Batch (Epoch83):   8%|▊         | 4/50 [00:00<00:07,  6.05it/s]
# Batch (Epoch83):  10%|█         | 5/50 [00:00<00:07,  6.06it/s]
# Batch (Epoch83):  12%|█▏        | 6/50 [00:00<00:07,  6.13it/s]
# Batch (Epoch83):  14%|█▍        | 7/50 [00:01<00:07,  5.92it/s]
# Batch (Epoch83):  16%|█▌        | 8/50 [00:01<00:07,  5.98it/s]
# Batch (Epoch83):  18%|█▊        | 9/50 [00:01<00:06,  5.99it/s]
# Batch (Epoch83):  20%|██        | 10/50 [00:01<00:06,  5.98it/s]
# Batch (Epoch83):  22%|██▏       | 11/50 [00:01<00:06,  6.05it/s]
# Batch (Epoch83):  24%|██▍       | 12/50 [00:01<00:06,  6.01it/s]
# Batch (Epoch83):  26%|██▌       | 13/50 [00:02<00:06,  5.94it/s]
# Batch (Epoch83):  28%|██▊       | 14/50 [00:02<00:05,  6.02it/s]
# Batch (Epoch83):  30%|███       | 15/50 [00:02<00:05,  6.00it/s]
# Batch (Epoch83):  32%|███▏      | 16/50 [00:02<00:05,  6.05it/s]
# Batch (Epoch83):  34%|███▍      | 17/50 [00:02<00:05,  6.06it/s]
# Batch (Epoch83):  36%|███▌      | 18/50 [00:02<00:05,  6.02it/s]
# Batch (Epoch83):  38%|███▊      | 19/50 [00:03<00:05,  6.01it/s]
# Batch (Epoch83):  40%|████      | 20/50 [00:03<00:05,  5.95it/s]
# Batch (Epoch83):  42%|████▏     | 21/50 [00:03<00:04,  5.99it/s]
# Batch (Epoch83):  44%|████▍     | 22/50 [00:03<00:04,  6.02it/s]
# Batch (Epoch83):  46%|████▌     | 23/50 [00:03<00:04,  5.96it/s]
# Batch (Epoch83):  48%|████▊     | 24/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch83):  50%|█████     | 25/50 [00:04<00:04,  6.00it/s]
# Batch (Epoch83):  52%|█████▏    | 26/50 [00:04<00:03,  6.04it/s]
# Batch (Epoch83):  54%|█████▍    | 27/50 [00:04<00:03,  6.02it/s]
# Batch (Epoch83):  56%|█████▌    | 28/50 [00:04<00:03,  5.95it/s]
# Batch (Epoch83):  58%|█████▊    | 29/50 [00:04<00:03,  6.05it/s]
# Batch (Epoch83):  60%|██████    | 30/50 [00:04<00:03,  5.97it/s]
# Batch (Epoch83):  62%|██████▏   | 31/50 [00:05<00:03,  5.94it/s]
# Batch (Epoch83):  64%|██████▍   | 32/50 [00:05<00:02,  6.03it/s]
# Batch (Epoch83):  66%|██████▌   | 33/50 [00:05<00:02,  6.00it/s]
# Batch (Epoch83):  68%|██████▊   | 34/50 [00:05<00:02,  5.95it/s]
# Batch (Epoch83):  70%|███████   | 35/50 [00:05<00:02,  5.93it/s]
# Batch (Epoch83):  72%|███████▏  | 36/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch83):  74%|███████▍  | 37/50 [00:06<00:02,  6.00it/s]
# Batch (Epoch83):  76%|███████▌  | 38/50 [00:06<00:01,  6.08it/s]
# Batch (Epoch83):  78%|███████▊  | 39/50 [00:06<00:01,  6.03it/s]
# Batch (Epoch83):  80%|████████  | 40/50 [00:06<00:01,  6.01it/s]
# Batch (Epoch83):  82%|████████▏ | 41/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch83):  84%|████████▍ | 42/50 [00:06<00:01,  6.08it/s]
# Batch (Epoch83):  86%|████████▌ | 43/50 [00:07<00:01,  6.09it/s]
# Batch (Epoch83):  88%|████████▊ | 44/50 [00:07<00:00,  6.11it/s]
# Batch (Epoch83):  90%|█████████ | 45/50 [00:07<00:00,  6.07it/s]
# Batch (Epoch83):  92%|█████████▏| 46/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch83):  94%|█████████▍| 47/50 [00:07<00:00,  5.98it/s]
# Batch (Epoch83):  96%|█████████▌| 48/50 [00:07<00:00,  5.79it/s]
# Batch (Epoch83):  98%|█████████▊| 49/50 [00:08<00:00,  5.93it/s]
# Batch (Epoch83): 100%|██████████| 50/50 [00:08<00:00,  6.01it/s]
# Epochs:  83%|████████▎ | 83/100 [11:21<02:20,  8.28s/it]
# Batch (Epoch84):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch84):   2%|▏         | 1/50 [00:00<00:06,  7.18it/s]
# Batch (Epoch84):   4%|▍         | 2/50 [00:00<00:07,  6.60it/s]
# Batch (Epoch84):   6%|▌         | 3/50 [00:00<00:07,  6.31it/s]
# Batch (Epoch84):   8%|▊         | 4/50 [00:00<00:07,  6.15it/s]
# Batch (Epoch84):  10%|█         | 5/50 [00:00<00:07,  6.14it/s]
# Batch (Epoch84):  12%|█▏        | 6/50 [00:00<00:07,  6.21it/s]
# Batch (Epoch84):  14%|█▍        | 7/50 [00:01<00:07,  6.02it/s]
# Batch (Epoch84):  16%|█▌        | 8/50 [00:01<00:07,  5.99it/s]
# Batch (Epoch84):  18%|█▊        | 9/50 [00:01<00:06,  6.01it/s]
# Batch (Epoch84):  20%|██        | 10/50 [00:01<00:06,  6.14it/s]
# Batch (Epoch84):  22%|██▏       | 11/50 [00:01<00:06,  5.89it/s]
# Batch (Epoch84):  24%|██▍       | 12/50 [00:01<00:06,  6.08it/s]
# Batch (Epoch84):  26%|██▌       | 13/50 [00:02<00:06,  6.02it/s]
# Batch (Epoch84):  28%|██▊       | 14/50 [00:02<00:06,  5.96it/s]
# Batch (Epoch84):  30%|███       | 15/50 [00:02<00:05,  5.91it/s]
# Batch (Epoch84):  32%|███▏      | 16/50 [00:02<00:05,  6.15it/s]
# Batch (Epoch84):  34%|███▍      | 17/50 [00:02<00:05,  5.99it/s]
# Batch (Epoch84):  36%|███▌      | 18/50 [00:02<00:05,  5.89it/s]
# Batch (Epoch84):  38%|███▊      | 19/50 [00:03<00:05,  6.05it/s]
# Batch (Epoch84):  40%|████      | 20/50 [00:03<00:05,  5.92it/s]
# Batch (Epoch84):  42%|████▏     | 21/50 [00:03<00:04,  6.14it/s]
# Batch (Epoch84):  44%|████▍     | 22/50 [00:03<00:04,  6.14it/s]
# Batch (Epoch84):  46%|████▌     | 23/50 [00:03<00:04,  6.00it/s]
# Batch (Epoch84):  48%|████▊     | 24/50 [00:03<00:04,  6.01it/s]
# Batch (Epoch84):  50%|█████     | 25/50 [00:04<00:04,  5.94it/s]
# Batch (Epoch84):  52%|█████▏    | 26/50 [00:04<00:04,  5.92it/s]
# Batch (Epoch84):  54%|█████▍    | 27/50 [00:04<00:03,  6.18it/s]
# Batch (Epoch84):  56%|█████▌    | 28/50 [00:04<00:03,  6.22it/s]
# Batch (Epoch84):  58%|█████▊    | 29/50 [00:04<00:03,  6.11it/s]
# Batch (Epoch84):  60%|██████    | 30/50 [00:04<00:03,  6.10it/s]
# Batch (Epoch84):  62%|██████▏   | 31/50 [00:05<00:03,  6.08it/s]
# Batch (Epoch84):  64%|██████▍   | 32/50 [00:05<00:02,  6.07it/s]
# Batch (Epoch84):  66%|██████▌   | 33/50 [00:05<00:02,  6.08it/s]
# Batch (Epoch84):  68%|██████▊   | 34/50 [00:05<00:02,  6.09it/s]
# Batch (Epoch84):  70%|███████   | 35/50 [00:05<00:02,  6.11it/s]
# Batch (Epoch84):  72%|███████▏  | 36/50 [00:05<00:02,  6.14it/s]
# Batch (Epoch84):  74%|███████▍  | 37/50 [00:06<00:02,  6.09it/s]
# Batch (Epoch84):  76%|███████▌  | 38/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch84):  78%|███████▊  | 39/50 [00:06<00:01,  6.08it/s]
# Batch (Epoch84):  80%|████████  | 40/50 [00:06<00:01,  6.10it/s]
# Batch (Epoch84):  82%|████████▏ | 41/50 [00:06<00:01,  6.10it/s]
# Batch (Epoch84):  84%|████████▍ | 42/50 [00:06<00:01,  6.12it/s]
# Batch (Epoch84):  86%|████████▌ | 43/50 [00:07<00:01,  6.08it/s]
# Batch (Epoch84):  88%|████████▊ | 44/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch84):  90%|█████████ | 45/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch84):  92%|█████████▏| 46/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch84):  94%|█████████▍| 47/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch84):  96%|█████████▌| 48/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch84):  98%|█████████▊| 49/50 [00:08<00:00,  6.07it/s]
# Batch (Epoch84): 100%|██████████| 50/50 [00:08<00:00,  6.07it/s]
# Epochs:  84%|████████▍ | 84/100 [11:29<02:12,  8.27s/it]
# Batch (Epoch85):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch85):   2%|▏         | 1/50 [00:00<00:07,  6.54it/s]
# Batch (Epoch85):   4%|▍         | 2/50 [00:00<00:07,  6.26it/s]
# Batch (Epoch85):   6%|▌         | 3/50 [00:00<00:07,  6.21it/s]
# Batch (Epoch85):   8%|▊         | 4/50 [00:00<00:07,  6.15it/s]
# Batch (Epoch85):  10%|█         | 5/50 [00:00<00:07,  6.12it/s]
# Batch (Epoch85):  12%|█▏        | 6/50 [00:00<00:07,  6.12it/s]
# Batch (Epoch85):  14%|█▍        | 7/50 [00:01<00:07,  6.11it/s]
# Batch (Epoch85):  16%|█▌        | 8/50 [00:01<00:06,  6.12it/s]
# Batch (Epoch85):  18%|█▊        | 9/50 [00:01<00:06,  6.09it/s]
# Batch (Epoch85):  20%|██        | 10/50 [00:01<00:06,  6.07it/s]
# Batch (Epoch85):  22%|██▏       | 11/50 [00:01<00:06,  6.04it/s]
# Batch (Epoch85):  24%|██▍       | 12/50 [00:01<00:06,  5.96it/s]
# Batch (Epoch85):  26%|██▌       | 13/50 [00:02<00:06,  6.03it/s]
# Batch (Epoch85):  28%|██▊       | 14/50 [00:02<00:06,  5.98it/s]
# Batch (Epoch85):  30%|███       | 15/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch85):  32%|███▏      | 16/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch85):  34%|███▍      | 17/50 [00:02<00:05,  6.04it/s]
# Batch (Epoch85):  36%|███▌      | 18/50 [00:02<00:05,  5.96it/s]
# Batch (Epoch85):  38%|███▊      | 19/50 [00:03<00:05,  5.93it/s]
# Batch (Epoch85):  40%|████      | 20/50 [00:03<00:04,  6.10it/s]
# Batch (Epoch85):  42%|████▏     | 21/50 [00:03<00:04,  6.02it/s]
# Batch (Epoch85):  44%|████▍     | 22/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch85):  46%|████▌     | 23/50 [00:03<00:04,  6.08it/s]
# Batch (Epoch85):  48%|████▊     | 24/50 [00:03<00:04,  6.08it/s]
# Batch (Epoch85):  50%|█████     | 25/50 [00:04<00:04,  6.08it/s]
# Batch (Epoch85):  52%|█████▏    | 26/50 [00:04<00:03,  6.01it/s]
# Batch (Epoch85):  54%|█████▍    | 27/50 [00:04<00:03,  6.11it/s]
# Batch (Epoch85):  56%|█████▌    | 28/50 [00:04<00:03,  5.91it/s]
# Batch (Epoch85):  58%|█████▊    | 29/50 [00:04<00:03,  6.00it/s]
# Batch (Epoch85):  60%|██████    | 30/50 [00:04<00:03,  6.07it/s]
# Batch (Epoch85):  62%|██████▏   | 31/50 [00:05<00:03,  6.11it/s]
# Batch (Epoch85):  64%|██████▍   | 32/50 [00:05<00:03,  5.95it/s]
# Batch (Epoch85):  66%|██████▌   | 33/50 [00:05<00:02,  6.15it/s]
# Batch (Epoch85):  68%|██████▊   | 34/50 [00:05<00:02,  6.15it/s]
# Batch (Epoch85):  70%|███████   | 35/50 [00:05<00:02,  6.15it/s]
# Batch (Epoch85):  72%|███████▏  | 36/50 [00:05<00:02,  6.13it/s]
# Batch (Epoch85):  74%|███████▍  | 37/50 [00:06<00:02,  6.02it/s]
# Batch (Epoch85):  76%|███████▌  | 38/50 [00:06<00:02,  5.97it/s]
# Batch (Epoch85):  78%|███████▊  | 39/50 [00:06<00:01,  6.01it/s]
# Batch (Epoch85):  80%|████████  | 40/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch85):  82%|████████▏ | 41/50 [00:06<00:01,  6.10it/s]
# Batch (Epoch85):  84%|████████▍ | 42/50 [00:06<00:01,  5.99it/s]
# Batch (Epoch85):  86%|████████▌ | 43/50 [00:07<00:01,  6.02it/s]
# Batch (Epoch85):  88%|████████▊ | 44/50 [00:07<00:00,  6.04it/s]
# Batch (Epoch85):  90%|█████████ | 45/50 [00:07<00:00,  6.08it/s]
# Batch (Epoch85):  92%|█████████▏| 46/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch85):  94%|█████████▍| 47/50 [00:07<00:00,  6.09it/s]
# Batch (Epoch85):  96%|█████████▌| 48/50 [00:07<00:00,  6.02it/s]
# Batch (Epoch85):  98%|█████████▊| 49/50 [00:08<00:00,  6.02it/s]
# Batch (Epoch85): 100%|██████████| 50/50 [00:08<00:00,  6.05it/s]
# Epochs:  85%|████████▌ | 85/100 [11:37<02:04,  8.27s/it]
# Batch (Epoch86):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch86):   2%|▏         | 1/50 [00:00<00:07,  6.30it/s]
# Batch (Epoch86):   4%|▍         | 2/50 [00:00<00:07,  6.29it/s]
# Batch (Epoch86):   6%|▌         | 3/50 [00:00<00:07,  6.20it/s]
# Batch (Epoch86):   8%|▊         | 4/50 [00:00<00:07,  6.14it/s]
# Batch (Epoch86):  10%|█         | 5/50 [00:00<00:07,  6.19it/s]
# Batch (Epoch86):  12%|█▏        | 6/50 [00:00<00:07,  6.09it/s]
# Batch (Epoch86):  14%|█▍        | 7/50 [00:01<00:07,  6.10it/s]
# Batch (Epoch86):  16%|█▌        | 8/50 [00:01<00:06,  6.09it/s]
# Batch (Epoch86):  18%|█▊        | 9/50 [00:01<00:06,  6.05it/s]
# Batch (Epoch86):  20%|██        | 10/50 [00:01<00:06,  5.85it/s]
# Batch (Epoch86):  22%|██▏       | 11/50 [00:01<00:06,  6.14it/s]
# Batch (Epoch86):  24%|██▍       | 12/50 [00:01<00:06,  6.01it/s]
# Batch (Epoch86):  26%|██▌       | 13/50 [00:02<00:06,  6.13it/s]
# Batch (Epoch86):  28%|██▊       | 14/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch86):  30%|███       | 15/50 [00:02<00:05,  6.06it/s]
# Batch (Epoch86):  32%|███▏      | 16/50 [00:02<00:05,  6.07it/s]
# Batch (Epoch86):  34%|███▍      | 17/50 [00:02<00:05,  6.02it/s]
# Batch (Epoch86):  36%|███▌      | 18/50 [00:02<00:05,  6.09it/s]
# Batch (Epoch86):  38%|███▊      | 19/50 [00:03<00:05,  6.00it/s]
# Batch (Epoch86):  40%|████      | 20/50 [00:03<00:04,  6.07it/s]
# Batch (Epoch86):  42%|████▏     | 21/50 [00:03<00:04,  6.17it/s]
# Batch (Epoch86):  44%|████▍     | 22/50 [00:03<00:04,  6.14it/s]
# Batch (Epoch86):  46%|████▌     | 23/50 [00:03<00:04,  6.15it/s]
# Batch (Epoch86):  48%|████▊     | 24/50 [00:03<00:04,  6.14it/s]
# Batch (Epoch86):  50%|█████     | 25/50 [00:04<00:04,  6.14it/s]
# Batch (Epoch86):  52%|█████▏    | 26/50 [00:04<00:03,  6.13it/s]
# Batch (Epoch86):  54%|█████▍    | 27/50 [00:04<00:03,  6.13it/s]
# Batch (Epoch86):  56%|█████▌    | 28/50 [00:04<00:03,  6.12it/s]
# Batch (Epoch86):  58%|█████▊    | 29/50 [00:04<00:03,  6.09it/s]
# Batch (Epoch86):  60%|██████    | 30/50 [00:04<00:03,  6.09it/s]
# Batch (Epoch86):  62%|██████▏   | 31/50 [00:05<00:03,  6.06it/s]
# Batch (Epoch86):  64%|██████▍   | 32/50 [00:05<00:02,  6.06it/s]
# Batch (Epoch86):  66%|██████▌   | 33/50 [00:05<00:02,  6.08it/s]
# Batch (Epoch86):  68%|██████▊   | 34/50 [00:05<00:02,  6.11it/s]
# Batch (Epoch86):  70%|███████   | 35/50 [00:05<00:02,  6.11it/s]
# Batch (Epoch86):  72%|███████▏  | 36/50 [00:05<00:02,  6.12it/s]
# Batch (Epoch86):  74%|███████▍  | 37/50 [00:06<00:02,  6.03it/s]
# Batch (Epoch86):  76%|███████▌  | 38/50 [00:06<00:01,  6.11it/s]
# Batch (Epoch86):  78%|███████▊  | 39/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch86):  80%|████████  | 40/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch86):  82%|████████▏ | 41/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch86):  84%|████████▍ | 42/50 [00:06<00:01,  6.10it/s]
# Batch (Epoch86):  86%|████████▌ | 43/50 [00:07<00:01,  6.11it/s]
# Batch (Epoch86):  88%|████████▊ | 44/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch86):  90%|█████████ | 45/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch86):  92%|█████████▏| 46/50 [00:07<00:00,  6.08it/s]
# Batch (Epoch86):  94%|█████████▍| 47/50 [00:07<00:00,  6.13it/s]
# Batch (Epoch86):  96%|█████████▌| 48/50 [00:07<00:00,  6.13it/s]
# Batch (Epoch86):  98%|█████████▊| 49/50 [00:08<00:00,  6.10it/s]
# Batch (Epoch86): 100%|██████████| 50/50 [00:08<00:00,  6.09it/s]
# Epochs:  86%|████████▌ | 86/100 [11:45<01:55,  8.25s/it]
# Batch (Epoch87):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch87):   2%|▏         | 1/50 [00:00<00:07,  6.45it/s]
# Batch (Epoch87):   4%|▍         | 2/50 [00:00<00:07,  6.24it/s]
# Batch (Epoch87):   6%|▌         | 3/50 [00:00<00:07,  6.22it/s]
# Batch (Epoch87):   8%|▊         | 4/50 [00:00<00:07,  6.16it/s]
# Batch (Epoch87):  10%|█         | 5/50 [00:00<00:07,  6.14it/s]
# Batch (Epoch87):  12%|█▏        | 6/50 [00:00<00:07,  6.14it/s]
# Batch (Epoch87):  14%|█▍        | 7/50 [00:01<00:07,  6.10it/s]
# Batch (Epoch87):  16%|█▌        | 8/50 [00:01<00:06,  6.13it/s]
# Batch (Epoch87):  18%|█▊        | 9/50 [00:01<00:06,  6.13it/s]
# Batch (Epoch87):  20%|██        | 10/50 [00:01<00:06,  6.13it/s]
# Batch (Epoch87):  22%|██▏       | 11/50 [00:01<00:06,  6.12it/s]
# Batch (Epoch87):  24%|██▍       | 12/50 [00:01<00:06,  6.01it/s]
# Batch (Epoch87):  26%|██▌       | 13/50 [00:02<00:06,  6.16it/s]
# Batch (Epoch87):  28%|██▊       | 14/50 [00:02<00:05,  6.17it/s]
# Batch (Epoch87):  30%|███       | 15/50 [00:02<00:05,  6.15it/s]
# Batch (Epoch87):  32%|███▏      | 16/50 [00:02<00:05,  6.15it/s]
# Batch (Epoch87):  34%|███▍      | 17/50 [00:02<00:05,  6.13it/s]
# Batch (Epoch87):  36%|███▌      | 18/50 [00:02<00:05,  6.10it/s]
# Batch (Epoch87):  38%|███▊      | 19/50 [00:03<00:05,  6.04it/s]
# Batch (Epoch87):  40%|████      | 20/50 [00:03<00:04,  6.09it/s]
# Batch (Epoch87):  42%|████▏     | 21/50 [00:03<00:04,  6.09it/s]
# Batch (Epoch87):  44%|████▍     | 22/50 [00:03<00:04,  6.10it/s]
# Batch (Epoch87):  46%|████▌     | 23/50 [00:03<00:04,  6.09it/s]
# Batch (Epoch87):  48%|████▊     | 24/50 [00:03<00:04,  6.10it/s]
# Batch (Epoch87):  50%|█████     | 25/50 [00:04<00:04,  6.09it/s]
# Batch (Epoch87):  52%|█████▏    | 26/50 [00:04<00:03,  6.10it/s]
# Batch (Epoch87):  54%|█████▍    | 27/50 [00:04<00:03,  6.06it/s]
# Batch (Epoch87):  56%|█████▌    | 28/50 [00:04<00:03,  6.13it/s]
# Batch (Epoch87):  58%|█████▊    | 29/50 [00:04<00:03,  6.09it/s]
# Batch (Epoch87):  60%|██████    | 30/50 [00:04<00:03,  6.11it/s]
# Batch (Epoch87):  62%|██████▏   | 31/50 [00:05<00:03,  6.08it/s]
# Batch (Epoch87):  64%|██████▍   | 32/50 [00:05<00:03,  5.98it/s]
# Batch (Epoch87):  66%|██████▌   | 33/50 [00:05<00:02,  6.03it/s]
# Batch (Epoch87):  68%|██████▊   | 34/50 [00:05<00:02,  6.06it/s]
# Batch (Epoch87):  70%|███████   | 35/50 [00:05<00:02,  6.03it/s]
# Batch (Epoch87):  72%|███████▏  | 36/50 [00:05<00:02,  5.97it/s]
# Batch (Epoch87):  74%|███████▍  | 37/50 [00:06<00:02,  6.00it/s]
# Batch (Epoch87):  76%|███████▌  | 38/50 [00:06<00:01,  6.06it/s]
# Batch (Epoch87):  78%|███████▊  | 39/50 [00:06<00:01,  6.08it/s]
# Batch (Epoch87):  80%|████████  | 40/50 [00:06<00:01,  6.12it/s]
# Batch (Epoch87):  82%|████████▏ | 41/50 [00:06<00:01,  6.13it/s]
# Batch (Epoch87):  84%|████████▍ | 42/50 [00:06<00:01,  6.06it/s]
# Batch (Epoch87):  86%|████████▌ | 43/50 [00:07<00:01,  6.04it/s]
# Batch (Epoch87):  88%|████████▊ | 44/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch87):  90%|█████████ | 45/50 [00:07<00:00,  5.99it/s]
# Batch (Epoch87):  92%|█████████▏| 46/50 [00:07<00:00,  6.14it/s]
# Batch (Epoch87):  94%|█████████▍| 47/50 [00:07<00:00,  5.99it/s]
# Batch (Epoch87):  96%|█████████▌| 48/50 [00:07<00:00,  6.05it/s]
# Batch (Epoch87):  98%|█████████▊| 49/50 [00:08<00:00,  5.99it/s]
# Batch (Epoch87): 100%|██████████| 50/50 [00:08<00:00,  6.08it/s]
# Epochs:  87%|████████▋ | 87/100 [11:54<01:47,  8.25s/it]
# Batch (Epoch88):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch88):   2%|▏         | 1/50 [00:00<00:06,  7.38it/s]
# Batch (Epoch88):   4%|▍         | 2/50 [00:00<00:07,  6.37it/s]
# Batch (Epoch88):   6%|▌         | 3/50 [00:00<00:07,  6.43it/s]
# Batch (Epoch88):   8%|▊         | 4/50 [00:00<00:07,  6.24it/s]
# Batch (Epoch88):  10%|█         | 5/50 [00:00<00:07,  6.22it/s]
# Batch (Epoch88):  12%|█▏        | 6/50 [00:00<00:07,  6.11it/s]
# Batch (Epoch88):  14%|█▍        | 7/50 [00:01<00:07,  6.01it/s]
# Batch (Epoch88):  16%|█▌        | 8/50 [00:01<00:07,  5.91it/s]
# Batch (Epoch88):  18%|█▊        | 9/50 [00:01<00:06,  5.96it/s]
# Batch (Epoch88):  20%|██        | 10/50 [00:01<00:06,  6.04it/s]
# Batch (Epoch88):  22%|██▏       | 11/50 [00:01<00:06,  6.18it/s]
# Batch (Epoch88):  24%|██▍       | 12/50 [00:01<00:06,  6.15it/s]
# Batch (Epoch88):  26%|██▌       | 13/50 [00:02<00:06,  6.09it/s]
# Batch (Epoch88):  28%|██▊       | 14/50 [00:02<00:05,  6.01it/s]
# Batch (Epoch88):  30%|███       | 15/50 [00:02<00:05,  6.13it/s]
# Batch (Epoch88):  32%|███▏      | 16/50 [00:02<00:05,  6.18it/s]
# Batch (Epoch88):  34%|███▍      | 17/50 [00:02<00:05,  6.00it/s]
# Batch (Epoch88):  36%|███▌      | 18/50 [00:02<00:05,  5.99it/s]
# Batch (Epoch88):  38%|███▊      | 19/50 [00:03<00:05,  5.98it/s]
# Batch (Epoch88):  40%|████      | 20/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch88):  42%|████▏     | 21/50 [00:03<00:04,  6.18it/s]
# Batch (Epoch88):  44%|████▍     | 22/50 [00:03<00:04,  6.09it/s]
# Batch (Epoch88):  46%|████▌     | 23/50 [00:03<00:04,  6.04it/s]
# Batch (Epoch88):  48%|████▊     | 24/50 [00:03<00:04,  6.08it/s]
# Batch (Epoch88):  50%|█████     | 25/50 [00:04<00:04,  6.12it/s]
# Batch (Epoch88):  52%|█████▏    | 26/50 [00:04<00:04,  5.94it/s]
# Batch (Epoch88):  54%|█████▍    | 27/50 [00:04<00:03,  6.07it/s]
# Batch (Epoch88):  56%|█████▌    | 28/50 [00:04<00:03,  6.02it/s]
# Batch (Epoch88):  58%|█████▊    | 29/50 [00:04<00:03,  6.02it/s]
# Batch (Epoch88):  60%|██████    | 30/50 [00:04<00:03,  6.20it/s]
# Batch (Epoch88):  62%|██████▏   | 31/50 [00:05<00:03,  6.17it/s]
# Batch (Epoch88):  64%|██████▍   | 32/50 [00:05<00:02,  6.08it/s]
# Batch (Epoch88):  66%|██████▌   | 33/50 [00:05<00:02,  6.21it/s]
# Batch (Epoch88):  68%|██████▊   | 34/50 [00:05<00:02,  6.18it/s]
# Batch (Epoch88):  70%|███████   | 35/50 [00:05<00:02,  6.18it/s]
# Batch (Epoch88):  72%|███████▏  | 36/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch88):  74%|███████▍  | 37/50 [00:06<00:02,  6.12it/s]
# Batch (Epoch88):  76%|███████▌  | 38/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch88):  78%|███████▊  | 39/50 [00:06<00:01,  6.16it/s]
# Batch (Epoch88):  80%|████████  | 40/50 [00:06<00:01,  6.21it/s]
# Batch (Epoch88):  82%|████████▏ | 41/50 [00:06<00:01,  6.18it/s]
# Batch (Epoch88):  84%|████████▍ | 42/50 [00:06<00:01,  6.15it/s]
# Batch (Epoch88):  86%|████████▌ | 43/50 [00:07<00:01,  6.16it/s]
# Batch (Epoch88):  88%|████████▊ | 44/50 [00:07<00:00,  6.15it/s]
# Batch (Epoch88):  90%|█████████ | 45/50 [00:07<00:00,  6.15it/s]
# Batch (Epoch88):  92%|█████████▏| 46/50 [00:07<00:00,  6.12it/s]
# Batch (Epoch88):  94%|█████████▍| 47/50 [00:07<00:00,  6.11it/s]
# Batch (Epoch88):  96%|█████████▌| 48/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch88):  98%|█████████▊| 49/50 [00:08<00:00,  6.06it/s]
# Batch (Epoch88): 100%|██████████| 50/50 [00:08<00:00,  6.11it/s]
# Epochs:  88%|████████▊ | 88/100 [12:02<01:38,  8.23s/it]
# Batch (Epoch89):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch89):   2%|▏         | 1/50 [00:00<00:07,  6.28it/s]
# Batch (Epoch89):   4%|▍         | 2/50 [00:00<00:07,  6.02it/s]
# Batch (Epoch89):   6%|▌         | 3/50 [00:00<00:07,  6.33it/s]
# Batch (Epoch89):   8%|▊         | 4/50 [00:00<00:07,  6.25it/s]
# Batch (Epoch89):  10%|█         | 5/50 [00:00<00:07,  6.19it/s]
# Batch (Epoch89):  12%|█▏        | 6/50 [00:00<00:07,  6.17it/s]
# Batch (Epoch89):  14%|█▍        | 7/50 [00:01<00:07,  6.12it/s]
# Batch (Epoch89):  16%|█▌        | 8/50 [00:01<00:06,  6.10it/s]
# Batch (Epoch89):  18%|█▊        | 9/50 [00:01<00:06,  6.10it/s]
# Batch (Epoch89):  20%|██        | 10/50 [00:01<00:06,  6.09it/s]
# Batch (Epoch89):  22%|██▏       | 11/50 [00:01<00:06,  6.07it/s]
# Batch (Epoch89):  24%|██▍       | 12/50 [00:01<00:06,  6.09it/s]
# Batch (Epoch89):  26%|██▌       | 13/50 [00:02<00:06,  6.10it/s]
# Batch (Epoch89):  28%|██▊       | 14/50 [00:02<00:05,  6.12it/s]
# Batch (Epoch89):  30%|███       | 15/50 [00:02<00:05,  6.13it/s]
# Batch (Epoch89):  32%|███▏      | 16/50 [00:02<00:05,  6.14it/s]
# Batch (Epoch89):  34%|███▍      | 17/50 [00:02<00:05,  6.10it/s]
# Batch (Epoch89):  36%|███▌      | 18/50 [00:02<00:05,  6.07it/s]
# Batch (Epoch89):  38%|███▊      | 19/50 [00:03<00:05,  6.12it/s]
# Batch (Epoch89):  40%|████      | 20/50 [00:03<00:04,  6.08it/s]
# Batch (Epoch89):  42%|████▏     | 21/50 [00:03<00:04,  6.07it/s]
# Batch (Epoch89):  44%|████▍     | 22/50 [00:03<00:04,  6.07it/s]
# Batch (Epoch89):  46%|████▌     | 23/50 [00:03<00:04,  6.05it/s]
# Batch (Epoch89):  48%|████▊     | 24/50 [00:03<00:04,  6.10it/s]
# Batch (Epoch89):  50%|█████     | 25/50 [00:04<00:04,  6.10it/s]
# Batch (Epoch89):  52%|█████▏    | 26/50 [00:04<00:03,  6.06it/s]
# Batch (Epoch89):  54%|█████▍    | 27/50 [00:04<00:03,  6.15it/s]
# Batch (Epoch89):  56%|█████▌    | 28/50 [00:04<00:03,  6.10it/s]
# Batch (Epoch89):  58%|█████▊    | 29/50 [00:04<00:03,  6.13it/s]
# Batch (Epoch89):  60%|██████    | 30/50 [00:04<00:03,  6.13it/s]
# Batch (Epoch89):  62%|██████▏   | 31/50 [00:05<00:03,  6.08it/s]
# Batch (Epoch89):  64%|██████▍   | 32/50 [00:05<00:02,  6.08it/s]
# Batch (Epoch89):  66%|██████▌   | 33/50 [00:05<00:02,  6.08it/s]
# Batch (Epoch89):  68%|██████▊   | 34/50 [00:05<00:02,  6.07it/s]
# Batch (Epoch89):  70%|███████   | 35/50 [00:05<00:02,  6.06it/s]
# Batch (Epoch89):  72%|███████▏  | 36/50 [00:05<00:02,  6.10it/s]
# Batch (Epoch89):  74%|███████▍  | 37/50 [00:06<00:02,  6.09it/s]
# Batch (Epoch89):  76%|███████▌  | 38/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch89):  78%|███████▊  | 39/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch89):  80%|████████  | 40/50 [00:06<00:01,  6.08it/s]
# Batch (Epoch89):  82%|████████▏ | 41/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch89):  84%|████████▍ | 42/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch89):  86%|████████▌ | 43/50 [00:07<00:01,  6.07it/s]
# Batch (Epoch89):  88%|████████▊ | 44/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch89):  90%|█████████ | 45/50 [00:07<00:00,  6.12it/s]
# Batch (Epoch89):  92%|█████████▏| 46/50 [00:07<00:00,  6.12it/s]
# Batch (Epoch89):  94%|█████████▍| 47/50 [00:07<00:00,  6.09it/s]
# Batch (Epoch89):  96%|█████████▌| 48/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch89):  98%|█████████▊| 49/50 [00:08<00:00,  6.05it/s]
# Batch (Epoch89): 100%|██████████| 50/50 [00:08<00:00,  6.09it/s]
# Epochs:  89%|████████▉ | 89/100 [12:10<01:30,  8.23s/it]
# Batch (Epoch90):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch90):   2%|▏         | 1/50 [00:00<00:07,  6.40it/s]
# Batch (Epoch90):   4%|▍         | 2/50 [00:00<00:07,  6.19it/s]
# Batch (Epoch90):   6%|▌         | 3/50 [00:00<00:07,  6.05it/s]
# Batch (Epoch90):   8%|▊         | 4/50 [00:00<00:07,  6.06it/s]
# Batch (Epoch90):  10%|█         | 5/50 [00:00<00:07,  5.95it/s]
# Batch (Epoch90):  12%|█▏        | 6/50 [00:00<00:07,  6.26it/s]
# Batch (Epoch90):  14%|█▍        | 7/50 [00:01<00:06,  6.18it/s]
# Batch (Epoch90):  16%|█▌        | 8/50 [00:01<00:06,  6.05it/s]
# Batch (Epoch90):  18%|█▊        | 9/50 [00:01<00:06,  6.15it/s]
# Batch (Epoch90):  20%|██        | 10/50 [00:01<00:06,  6.14it/s]
# Batch (Epoch90):  22%|██▏       | 11/50 [00:01<00:06,  6.14it/s]
# Batch (Epoch90):  24%|██▍       | 12/50 [00:01<00:06,  6.09it/s]
# Batch (Epoch90):  26%|██▌       | 13/50 [00:02<00:06,  6.06it/s]
# Batch (Epoch90):  28%|██▊       | 14/50 [00:02<00:06,  5.98it/s]
# Batch (Epoch90):  30%|███       | 15/50 [00:02<00:05,  6.04it/s]
# Batch (Epoch90):  32%|███▏      | 16/50 [00:02<00:05,  6.01it/s]
# Batch (Epoch90):  34%|███▍      | 17/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch90):  36%|███▌      | 18/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch90):  38%|███▊      | 19/50 [00:03<00:05,  6.04it/s]
# Batch (Epoch90):  40%|████      | 20/50 [00:03<00:05,  5.95it/s]
# Batch (Epoch90):  42%|████▏     | 21/50 [00:03<00:04,  5.98it/s]
# Batch (Epoch90):  44%|████▍     | 22/50 [00:03<00:04,  6.13it/s]
# Batch (Epoch90):  46%|████▌     | 23/50 [00:03<00:04,  6.13it/s]
# Batch (Epoch90):  48%|████▊     | 24/50 [00:03<00:04,  6.12it/s]
# Batch (Epoch90):  50%|█████     | 25/50 [00:04<00:04,  6.11it/s]
# Batch (Epoch90):  52%|█████▏    | 26/50 [00:04<00:03,  6.07it/s]
# Batch (Epoch90):  54%|█████▍    | 27/50 [00:04<00:03,  6.03it/s]
# Batch (Epoch90):  56%|█████▌    | 28/50 [00:04<00:03,  5.82it/s]
# Batch (Epoch90):  58%|█████▊    | 29/50 [00:04<00:03,  6.14it/s]
# Batch (Epoch90):  60%|██████    | 30/50 [00:04<00:03,  6.16it/s]
# Batch (Epoch90):  62%|██████▏   | 31/50 [00:05<00:03,  6.16it/s]
# Batch (Epoch90):  64%|██████▍   | 32/50 [00:05<00:02,  6.14it/s]
# Batch (Epoch90):  66%|██████▌   | 33/50 [00:05<00:02,  5.94it/s]
# Batch (Epoch90):  68%|██████▊   | 34/50 [00:05<00:02,  6.05it/s]
# Batch (Epoch90):  70%|███████   | 35/50 [00:05<00:02,  6.09it/s]
# Batch (Epoch90):  72%|███████▏  | 36/50 [00:05<00:02,  5.89it/s]
# Batch (Epoch90):  74%|███████▍  | 37/50 [00:06<00:02,  6.00it/s]
# Batch (Epoch90):  76%|███████▌  | 38/50 [00:06<00:01,  6.11it/s]
# Batch (Epoch90):  78%|███████▊  | 39/50 [00:06<00:01,  6.13it/s]
# Batch (Epoch90):  80%|████████  | 40/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch90):  82%|████████▏ | 41/50 [00:06<00:01,  6.10it/s]
# Batch (Epoch90):  84%|████████▍ | 42/50 [00:06<00:01,  6.03it/s]
# Batch (Epoch90):  86%|████████▌ | 43/50 [00:07<00:01,  6.04it/s]
# Batch (Epoch90):  88%|████████▊ | 44/50 [00:07<00:00,  6.07it/s]
# Batch (Epoch90):  90%|█████████ | 45/50 [00:07<00:00,  5.90it/s]
# Batch (Epoch90):  92%|█████████▏| 46/50 [00:07<00:00,  6.02it/s]
# Batch (Epoch90):  94%|█████████▍| 47/50 [00:07<00:00,  5.95it/s]
# Batch (Epoch90):  96%|█████████▌| 48/50 [00:07<00:00,  6.04it/s]
# Batch (Epoch90):  98%|█████████▊| 49/50 [00:08<00:00,  6.07it/s]
# Batch (Epoch90): 100%|██████████| 50/50 [00:08<00:00,  6.05it/s]
# Epochs:  90%|█████████ | 90/100 [12:18<01:22,  8.24s/it]
# Batch (Epoch91):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch91):   2%|▏         | 1/50 [00:00<00:07,  6.66it/s]
# Batch (Epoch91):   4%|▍         | 2/50 [00:00<00:07,  6.63it/s]
# Batch (Epoch91):   6%|▌         | 3/50 [00:00<00:07,  6.03it/s]
# Batch (Epoch91):   8%|▊         | 4/50 [00:00<00:07,  6.13it/s]
# Batch (Epoch91):  10%|█         | 5/50 [00:00<00:07,  6.09it/s]
# Batch (Epoch91):  12%|█▏        | 6/50 [00:00<00:07,  6.24it/s]
# Batch (Epoch91):  14%|█▍        | 7/50 [00:01<00:07,  6.05it/s]
# Batch (Epoch91):  16%|█▌        | 8/50 [00:01<00:07,  5.98it/s]
# Batch (Epoch91):  18%|█▊        | 9/50 [00:01<00:06,  6.06it/s]
# Batch (Epoch91):  20%|██        | 10/50 [00:01<00:06,  6.20it/s]
# Batch (Epoch91):  22%|██▏       | 11/50 [00:01<00:06,  6.16it/s]
# Batch (Epoch91):  24%|██▍       | 12/50 [00:01<00:06,  6.24it/s]
# Batch (Epoch91):  26%|██▌       | 13/50 [00:02<00:05,  6.18it/s]
# Batch (Epoch91):  28%|██▊       | 14/50 [00:02<00:05,  6.11it/s]
# Batch (Epoch91):  30%|███       | 15/50 [00:02<00:05,  6.09it/s]
# Batch (Epoch91):  32%|███▏      | 16/50 [00:02<00:05,  6.06it/s]
# Batch (Epoch91):  34%|███▍      | 17/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch91):  36%|███▌      | 18/50 [00:02<00:05,  6.10it/s]
# Batch (Epoch91):  38%|███▊      | 19/50 [00:03<00:05,  6.10it/s]
# Batch (Epoch91):  40%|████      | 20/50 [00:03<00:04,  6.07it/s]
# Batch (Epoch91):  42%|████▏     | 21/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch91):  44%|████▍     | 22/50 [00:03<00:04,  6.03it/s]
# Batch (Epoch91):  46%|████▌     | 23/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch91):  48%|████▊     | 24/50 [00:03<00:04,  6.08it/s]
# Batch (Epoch91):  50%|█████     | 25/50 [00:04<00:04,  6.09it/s]
# Batch (Epoch91):  52%|█████▏    | 26/50 [00:04<00:03,  6.06it/s]
# Batch (Epoch91):  54%|█████▍    | 27/50 [00:04<00:03,  6.06it/s]
# Batch (Epoch91):  56%|█████▌    | 28/50 [00:04<00:03,  6.03it/s]
# Batch (Epoch91):  58%|█████▊    | 29/50 [00:04<00:03,  6.05it/s]
# Batch (Epoch91):  60%|██████    | 30/50 [00:04<00:03,  6.06it/s]
# Batch (Epoch91):  62%|██████▏   | 31/50 [00:05<00:03,  6.07it/s]
# Batch (Epoch91):  64%|██████▍   | 32/50 [00:05<00:02,  6.07it/s]
# Batch (Epoch91):  66%|██████▌   | 33/50 [00:05<00:02,  6.07it/s]
# Batch (Epoch91):  68%|██████▊   | 34/50 [00:05<00:02,  5.98it/s]
# Batch (Epoch91):  70%|███████   | 35/50 [00:05<00:02,  6.08it/s]
# Batch (Epoch91):  72%|███████▏  | 36/50 [00:05<00:02,  6.06it/s]
# Batch (Epoch91):  74%|███████▍  | 37/50 [00:06<00:02,  6.06it/s]
# Batch (Epoch91):  76%|███████▌  | 38/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch91):  78%|███████▊  | 39/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch91):  80%|████████  | 40/50 [00:06<00:01,  6.11it/s]
# Batch (Epoch91):  82%|████████▏ | 41/50 [00:06<00:01,  6.11it/s]
# Batch (Epoch91):  84%|████████▍ | 42/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch91):  86%|████████▌ | 43/50 [00:07<00:01,  6.06it/s]
# Batch (Epoch91):  88%|████████▊ | 44/50 [00:07<00:00,  6.04it/s]
# Batch (Epoch91):  90%|█████████ | 45/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch91):  92%|█████████▏| 46/50 [00:07<00:00,  6.07it/s]
# Batch (Epoch91):  94%|█████████▍| 47/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch91):  96%|█████████▌| 48/50 [00:07<00:00,  6.08it/s]
# Batch (Epoch91):  98%|█████████▊| 49/50 [00:08<00:00,  6.08it/s]
# Batch (Epoch91): 100%|██████████| 50/50 [00:08<00:00,  6.08it/s]
# Epochs:  91%|█████████ | 91/100 [12:27<01:14,  8.24s/it]
# Batch (Epoch92):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch92):   2%|▏         | 1/50 [00:00<00:07,  6.37it/s]
# Batch (Epoch92):   4%|▍         | 2/50 [00:00<00:07,  6.16it/s]
# Batch (Epoch92):   6%|▌         | 3/50 [00:00<00:07,  6.17it/s]
# Batch (Epoch92):   8%|▊         | 4/50 [00:00<00:07,  6.15it/s]
# Batch (Epoch92):  10%|█         | 5/50 [00:00<00:07,  6.17it/s]
# Batch (Epoch92):  12%|█▏        | 6/50 [00:00<00:07,  6.11it/s]
# Batch (Epoch92):  14%|█▍        | 7/50 [00:01<00:07,  6.10it/s]
# Batch (Epoch92):  16%|█▌        | 8/50 [00:01<00:06,  6.07it/s]
# Batch (Epoch92):  18%|█▊        | 9/50 [00:01<00:06,  5.95it/s]
# Batch (Epoch92):  20%|██        | 10/50 [00:01<00:06,  6.08it/s]
# Batch (Epoch92):  22%|██▏       | 11/50 [00:01<00:06,  6.09it/s]
# Batch (Epoch92):  24%|██▍       | 12/50 [00:01<00:06,  6.08it/s]
# Batch (Epoch92):  26%|██▌       | 13/50 [00:02<00:06,  6.10it/s]
# Batch (Epoch92):  28%|██▊       | 14/50 [00:02<00:05,  6.09it/s]
# Batch (Epoch92):  30%|███       | 15/50 [00:02<00:05,  6.07it/s]
# Batch (Epoch92):  32%|███▏      | 16/50 [00:02<00:05,  6.04it/s]
# Batch (Epoch92):  34%|███▍      | 17/50 [00:02<00:05,  6.06it/s]
# Batch (Epoch92):  36%|███▌      | 18/50 [00:02<00:05,  6.02it/s]
# Batch (Epoch92):  38%|███▊      | 19/50 [00:03<00:05,  6.08it/s]
# Batch (Epoch92):  40%|████      | 20/50 [00:03<00:04,  6.01it/s]
# Batch (Epoch92):  42%|████▏     | 21/50 [00:03<00:04,  5.98it/s]
# Batch (Epoch92):  44%|████▍     | 22/50 [00:03<00:04,  6.01it/s]
# Batch (Epoch92):  46%|████▌     | 23/50 [00:03<00:04,  5.91it/s]
# Batch (Epoch92):  48%|████▊     | 24/50 [00:03<00:04,  6.08it/s]
# Batch (Epoch92):  50%|█████     | 25/50 [00:04<00:04,  6.01it/s]
# Batch (Epoch92):  52%|█████▏    | 26/50 [00:04<00:03,  6.08it/s]
# Batch (Epoch92):  54%|█████▍    | 27/50 [00:04<00:03,  5.98it/s]
# Batch (Epoch92):  56%|█████▌    | 28/50 [00:04<00:03,  5.81it/s]
# Batch (Epoch92):  58%|█████▊    | 29/50 [00:04<00:03,  5.94it/s]
# Batch (Epoch92):  60%|██████    | 30/50 [00:04<00:03,  5.97it/s]
# Batch (Epoch92):  62%|██████▏   | 31/50 [00:05<00:03,  6.11it/s]
# Batch (Epoch92):  64%|██████▍   | 32/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch92):  66%|██████▌   | 33/50 [00:05<00:02,  6.03it/s]
# Batch (Epoch92):  68%|██████▊   | 34/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch92):  70%|███████   | 35/50 [00:05<00:02,  6.15it/s]
# Batch (Epoch92):  72%|███████▏  | 36/50 [00:05<00:02,  6.14it/s]
# Batch (Epoch92):  74%|███████▍  | 37/50 [00:06<00:02,  6.09it/s]
# Batch (Epoch92):  76%|███████▌  | 38/50 [00:06<00:01,  6.11it/s]
# Batch (Epoch92):  78%|███████▊  | 39/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch92):  80%|████████  | 40/50 [00:06<00:01,  6.03it/s]
# Batch (Epoch92):  82%|████████▏ | 41/50 [00:06<00:01,  5.91it/s]
# Batch (Epoch92):  84%|████████▍ | 42/50 [00:06<00:01,  6.10it/s]
# Batch (Epoch92):  86%|████████▌ | 43/50 [00:07<00:01,  6.09it/s]
# Batch (Epoch92):  88%|████████▊ | 44/50 [00:07<00:00,  6.13it/s]
# Batch (Epoch92):  90%|█████████ | 45/50 [00:07<00:00,  6.11it/s]
# Batch (Epoch92):  92%|█████████▏| 46/50 [00:07<00:00,  6.11it/s]
# Batch (Epoch92):  94%|█████████▍| 47/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch92):  96%|█████████▌| 48/50 [00:07<00:00,  6.05it/s]
# Batch (Epoch92):  98%|█████████▊| 49/50 [00:08<00:00,  5.97it/s]
# Batch (Epoch92): 100%|██████████| 50/50 [00:08<00:00,  6.04it/s]
# Epochs:  92%|█████████▏| 92/100 [12:35<01:06,  8.25s/it]
# Batch (Epoch93):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch93):   2%|▏         | 1/50 [00:00<00:07,  6.63it/s]
# Batch (Epoch93):   4%|▍         | 2/50 [00:00<00:07,  6.25it/s]
# Batch (Epoch93):   6%|▌         | 3/50 [00:00<00:07,  6.45it/s]
# Batch (Epoch93):   8%|▊         | 4/50 [00:00<00:07,  6.10it/s]
# Batch (Epoch93):  10%|█         | 5/50 [00:00<00:07,  5.82it/s]
# Batch (Epoch93):  12%|█▏        | 6/50 [00:00<00:07,  6.23it/s]
# Batch (Epoch93):  14%|█▍        | 7/50 [00:01<00:07,  6.12it/s]
# Batch (Epoch93):  16%|█▌        | 8/50 [00:01<00:07,  5.98it/s]
# Batch (Epoch93):  18%|█▊        | 9/50 [00:01<00:06,  6.04it/s]
# Batch (Epoch93):  20%|██        | 10/50 [00:01<00:06,  5.93it/s]
# Batch (Epoch93):  22%|██▏       | 11/50 [00:01<00:06,  5.94it/s]
# Batch (Epoch93):  24%|██▍       | 12/50 [00:01<00:06,  6.17it/s]
# Batch (Epoch93):  26%|██▌       | 13/50 [00:02<00:06,  6.12it/s]
# Batch (Epoch93):  28%|██▊       | 14/50 [00:02<00:05,  6.05it/s]
# Batch (Epoch93):  30%|███       | 15/50 [00:02<00:05,  6.05it/s]
# Batch (Epoch93):  32%|███▏      | 16/50 [00:02<00:05,  5.91it/s]
# Batch (Epoch93):  34%|███▍      | 17/50 [00:02<00:05,  5.93it/s]
# Batch (Epoch93):  36%|███▌      | 18/50 [00:02<00:05,  6.12it/s]
# Batch (Epoch93):  38%|███▊      | 19/50 [00:03<00:05,  6.00it/s]
# Batch (Epoch93):  40%|████      | 20/50 [00:03<00:04,  6.12it/s]
# Batch (Epoch93):  42%|████▏     | 21/50 [00:03<00:04,  6.01it/s]
# Batch (Epoch93):  44%|████▍     | 22/50 [00:03<00:04,  6.11it/s]
# Batch (Epoch93):  46%|████▌     | 23/50 [00:03<00:04,  5.93it/s]
# Batch (Epoch93):  48%|████▊     | 24/50 [00:03<00:04,  5.98it/s]
# Batch (Epoch93):  50%|█████     | 25/50 [00:04<00:04,  6.06it/s]
# Batch (Epoch93):  52%|█████▏    | 26/50 [00:04<00:03,  6.08it/s]
# Batch (Epoch93):  54%|█████▍    | 27/50 [00:04<00:03,  5.89it/s]
# Batch (Epoch93):  56%|█████▌    | 28/50 [00:04<00:03,  6.02it/s]
# Batch (Epoch93):  58%|█████▊    | 29/50 [00:04<00:03,  5.97it/s]
# Batch (Epoch93):  60%|██████    | 30/50 [00:04<00:03,  6.13it/s]
# Batch (Epoch93):  62%|██████▏   | 31/50 [00:05<00:03,  6.04it/s]
# Batch (Epoch93):  64%|██████▍   | 32/50 [00:05<00:02,  6.16it/s]
# Batch (Epoch93):  66%|██████▌   | 33/50 [00:05<00:02,  6.16it/s]
# Batch (Epoch93):  68%|██████▊   | 34/50 [00:05<00:02,  6.13it/s]
# Batch (Epoch93):  70%|███████   | 35/50 [00:05<00:02,  6.13it/s]
# Batch (Epoch93):  72%|███████▏  | 36/50 [00:05<00:02,  6.12it/s]
# Batch (Epoch93):  74%|███████▍  | 37/50 [00:06<00:02,  6.09it/s]
# Batch (Epoch93):  76%|███████▌  | 38/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch93):  78%|███████▊  | 39/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch93):  80%|████████  | 40/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch93):  82%|████████▏ | 41/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch93):  84%|████████▍ | 42/50 [00:06<00:01,  6.08it/s]
# Batch (Epoch93):  86%|████████▌ | 43/50 [00:07<00:01,  6.07it/s]
# Batch (Epoch93):  88%|████████▊ | 44/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch93):  90%|█████████ | 45/50 [00:07<00:00,  6.09it/s]
# Batch (Epoch93):  92%|█████████▏| 46/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch93):  94%|█████████▍| 47/50 [00:07<00:00,  6.05it/s]
# Batch (Epoch93):  96%|█████████▌| 48/50 [00:07<00:00,  5.98it/s]
# Batch (Epoch93):  98%|█████████▊| 49/50 [00:08<00:00,  6.08it/s]
# Batch (Epoch93): 100%|██████████| 50/50 [00:08<00:00,  6.06it/s]
# Epochs:  93%|█████████▎| 93/100 [12:43<00:57,  8.26s/it]
# Batch (Epoch94):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch94):   2%|▏         | 1/50 [00:00<00:07,  6.47it/s]
# Batch (Epoch94):   4%|▍         | 2/50 [00:00<00:07,  6.20it/s]
# Batch (Epoch94):   6%|▌         | 3/50 [00:00<00:07,  6.15it/s]
# Batch (Epoch94):   8%|▊         | 4/50 [00:00<00:07,  6.09it/s]
# Batch (Epoch94):  10%|█         | 5/50 [00:00<00:07,  6.09it/s]
# Batch (Epoch94):  12%|█▏        | 6/50 [00:00<00:07,  6.10it/s]
# Batch (Epoch94):  14%|█▍        | 7/50 [00:01<00:07,  6.10it/s]
# Batch (Epoch94):  16%|█▌        | 8/50 [00:01<00:06,  6.05it/s]
# Batch (Epoch94):  18%|█▊        | 9/50 [00:01<00:06,  6.06it/s]
# Batch (Epoch94):  20%|██        | 10/50 [00:01<00:06,  6.04it/s]
# Batch (Epoch94):  22%|██▏       | 11/50 [00:01<00:06,  6.04it/s]
# Batch (Epoch94):  24%|██▍       | 12/50 [00:01<00:06,  6.06it/s]
# Batch (Epoch94):  26%|██▌       | 13/50 [00:02<00:06,  6.10it/s]
# Batch (Epoch94):  28%|██▊       | 14/50 [00:02<00:05,  6.10it/s]
# Batch (Epoch94):  30%|███       | 15/50 [00:02<00:05,  6.03it/s]
# Batch (Epoch94):  32%|███▏      | 16/50 [00:02<00:05,  6.06it/s]
# Batch (Epoch94):  34%|███▍      | 17/50 [00:02<00:05,  6.05it/s]
# Batch (Epoch94):  36%|███▌      | 18/50 [00:02<00:05,  6.05it/s]
# Batch (Epoch94):  38%|███▊      | 19/50 [00:03<00:05,  6.06it/s]
# Batch (Epoch94):  40%|████      | 20/50 [00:03<00:04,  6.07it/s]
# Batch (Epoch94):  42%|████▏     | 21/50 [00:03<00:04,  6.05it/s]
# Batch (Epoch94):  44%|████▍     | 22/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch94):  46%|████▌     | 23/50 [00:03<00:04,  5.94it/s]
# Batch (Epoch94):  48%|████▊     | 24/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch94):  50%|█████     | 25/50 [00:04<00:04,  6.06it/s]
# Batch (Epoch94):  52%|█████▏    | 26/50 [00:04<00:03,  6.07it/s]
# Batch (Epoch94):  54%|█████▍    | 27/50 [00:04<00:03,  6.08it/s]
# Batch (Epoch94):  56%|█████▌    | 28/50 [00:04<00:03,  6.01it/s]
# Batch (Epoch94):  58%|█████▊    | 29/50 [00:04<00:03,  6.02it/s]
# Batch (Epoch94):  60%|██████    | 30/50 [00:04<00:03,  6.02it/s]
# Batch (Epoch94):  62%|██████▏   | 31/50 [00:05<00:03,  6.04it/s]
# Batch (Epoch94):  64%|██████▍   | 32/50 [00:05<00:02,  6.03it/s]
# Batch (Epoch94):  66%|██████▌   | 33/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch94):  68%|██████▊   | 34/50 [00:05<00:02,  6.07it/s]
# Batch (Epoch94):  70%|███████   | 35/50 [00:05<00:02,  6.05it/s]
# Batch (Epoch94):  72%|███████▏  | 36/50 [00:05<00:02,  6.04it/s]
# Batch (Epoch94):  74%|███████▍  | 37/50 [00:06<00:02,  6.04it/s]
# Batch (Epoch94):  76%|███████▌  | 38/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch94):  78%|███████▊  | 39/50 [00:06<00:01,  6.08it/s]
# Batch (Epoch94):  80%|████████  | 40/50 [00:06<00:01,  6.08it/s]
# Batch (Epoch94):  82%|████████▏ | 41/50 [00:06<00:01,  6.10it/s]
# Batch (Epoch94):  84%|████████▍ | 42/50 [00:06<00:01,  5.98it/s]
# Batch (Epoch94):  86%|████████▌ | 43/50 [00:07<00:01,  5.97it/s]
# Batch (Epoch94):  88%|████████▊ | 44/50 [00:07<00:01,  5.99it/s]
# Batch (Epoch94):  90%|█████████ | 45/50 [00:07<00:00,  6.01it/s]
# Batch (Epoch94):  92%|█████████▏| 46/50 [00:07<00:00,  6.07it/s]
# Batch (Epoch94):  94%|█████████▍| 47/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch94):  96%|█████████▌| 48/50 [00:07<00:00,  5.97it/s]
# Batch (Epoch94):  98%|█████████▊| 49/50 [00:08<00:00,  6.09it/s]
# Batch (Epoch94): 100%|██████████| 50/50 [00:08<00:00,  6.05it/s]
# Epochs:  94%|█████████▍| 94/100 [12:51<00:49,  8.26s/it]
# Batch (Epoch95):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch95):   2%|▏         | 1/50 [00:00<00:07,  6.78it/s]
# Batch (Epoch95):   4%|▍         | 2/50 [00:00<00:07,  6.27it/s]
# Batch (Epoch95):   6%|▌         | 3/50 [00:00<00:07,  5.89it/s]
# Batch (Epoch95):   8%|▊         | 4/50 [00:00<00:07,  6.21it/s]
# Batch (Epoch95):  10%|█         | 5/50 [00:00<00:07,  6.10it/s]
# Batch (Epoch95):  12%|█▏        | 6/50 [00:00<00:07,  6.04it/s]
# Batch (Epoch95):  14%|█▍        | 7/50 [00:01<00:07,  6.07it/s]
# Batch (Epoch95):  16%|█▌        | 8/50 [00:01<00:07,  5.97it/s]
# Batch (Epoch95):  18%|█▊        | 9/50 [00:01<00:06,  6.06it/s]
# Batch (Epoch95):  20%|██        | 10/50 [00:01<00:06,  5.89it/s]
# Batch (Epoch95):  22%|██▏       | 11/50 [00:01<00:06,  5.95it/s]
# Batch (Epoch95):  24%|██▍       | 12/50 [00:01<00:06,  6.03it/s]
# Batch (Epoch95):  26%|██▌       | 13/50 [00:02<00:06,  6.10it/s]
# Batch (Epoch95):  28%|██▊       | 14/50 [00:02<00:06,  5.96it/s]
# Batch (Epoch95):  30%|███       | 15/50 [00:02<00:05,  6.04it/s]
# Batch (Epoch95):  32%|███▏      | 16/50 [00:02<00:05,  5.88it/s]
# Batch (Epoch95):  34%|███▍      | 17/50 [00:02<00:05,  6.02it/s]
# Batch (Epoch95):  36%|███▌      | 18/50 [00:02<00:05,  6.03it/s]
# Batch (Epoch95):  38%|███▊      | 19/50 [00:03<00:05,  6.09it/s]
# Batch (Epoch95):  40%|████      | 20/50 [00:03<00:04,  6.07it/s]
# Batch (Epoch95):  42%|████▏     | 21/50 [00:03<00:04,  6.05it/s]
# Batch (Epoch95):  44%|████▍     | 22/50 [00:03<00:04,  6.04it/s]
# Batch (Epoch95):  46%|████▌     | 23/50 [00:03<00:04,  5.88it/s]
# Batch (Epoch95):  48%|████▊     | 24/50 [00:03<00:04,  6.05it/s]
# Batch (Epoch95):  50%|█████     | 25/50 [00:04<00:04,  5.86it/s]
# Batch (Epoch95):  52%|█████▏    | 26/50 [00:04<00:03,  6.02it/s]
# Batch (Epoch95):  54%|█████▍    | 27/50 [00:04<00:03,  5.96it/s]
# Batch (Epoch95):  56%|█████▌    | 28/50 [00:04<00:03,  5.99it/s]
# Batch (Epoch95):  58%|█████▊    | 29/50 [00:04<00:03,  6.09it/s]
# Batch (Epoch95):  60%|██████    | 30/50 [00:04<00:03,  6.15it/s]
# Batch (Epoch95):  62%|██████▏   | 31/50 [00:05<00:03,  6.12it/s]
# Batch (Epoch95):  64%|██████▍   | 32/50 [00:05<00:02,  6.08it/s]
# Batch (Epoch95):  66%|██████▌   | 33/50 [00:05<00:02,  6.06it/s]
# Batch (Epoch95):  68%|██████▊   | 34/50 [00:05<00:02,  6.00it/s]
# Batch (Epoch95):  70%|███████   | 35/50 [00:05<00:02,  5.97it/s]
# Batch (Epoch95):  72%|███████▏  | 36/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch95):  74%|███████▍  | 37/50 [00:06<00:02,  6.08it/s]
# Batch (Epoch95):  76%|███████▌  | 38/50 [00:06<00:01,  6.08it/s]
# Batch (Epoch95):  78%|███████▊  | 39/50 [00:06<00:01,  5.88it/s]
# Batch (Epoch95):  80%|████████  | 40/50 [00:06<00:01,  5.96it/s]
# Batch (Epoch95):  82%|████████▏ | 41/50 [00:06<00:01,  5.99it/s]
# Batch (Epoch95):  84%|████████▍ | 42/50 [00:06<00:01,  6.06it/s]
# Batch (Epoch95):  86%|████████▌ | 43/50 [00:07<00:01,  5.99it/s]
# Batch (Epoch95):  88%|████████▊ | 44/50 [00:07<00:00,  6.02it/s]
# Batch (Epoch95):  90%|█████████ | 45/50 [00:07<00:00,  5.94it/s]
# Batch (Epoch95):  92%|█████████▏| 46/50 [00:07<00:00,  6.02it/s]
# Batch (Epoch95):  94%|█████████▍| 47/50 [00:07<00:00,  5.96it/s]
# ...
# Batch (Epoch96):  26%|██▌       | 13/50 [00:02<00:06,  6.05it/s]
# Batch (Epoch96):  28%|██▊       | 14/50 [00:02<00:05,  6.07it/s]
# Batch (Epoch96):  30%|███       | 15/50 [00:02<00:05,  6.07it/s]
# Batch (Epoch96):  32%|███▏      | 16/50 [00:02<00:05,  6.06it/s]
# Batch (Epoch96):  34%|███▍      | 17/50 [00:02<00:05,  6.01it/s]
# Batch (Epoch96):  36%|███▌      | 18/50 [00:02<00:05,  5.95it/s]
# Batch (Epoch96):  38%|███▊      | 19/50 [00:03<00:05,  6.03it/s]
# Batch (Epoch96):  40%|████      | 20/50 [00:03<00:04,  6.01it/s]
# Batch (Epoch96):  42%|████▏     | 21/50 [00:03<00:04,  6.09it/s]
# Batch (Epoch96):  44%|████▍     | 22/50 [00:03<00:04,  6.08it/s]
# Batch (Epoch96):  46%|████▌     | 23/50 [00:03<00:04,  6.05it/s]
# Batch (Epoch96):  48%|████▊     | 24/50 [00:03<00:04,  6.03it/s]
# Batch (Epoch96):  50%|█████     | 25/50 [00:04<00:04,  6.02it/s]
# Batch (Epoch96):  52%|█████▏    | 26/50 [00:04<00:03,  6.05it/s]
# Batch (Epoch96):  54%|█████▍    | 27/50 [00:04<00:03,  6.03it/s]
# Batch (Epoch96):  56%|█████▌    | 28/50 [00:04<00:03,  6.08it/s]
# Batch (Epoch96):  58%|█████▊    | 29/50 [00:04<00:03,  6.04it/s]
# Batch (Epoch96):  60%|██████    | 30/50 [00:04<00:03,  6.02it/s]
# Batch (Epoch96):  62%|██████▏   | 31/50 [00:05<00:03,  6.03it/s]
# Batch (Epoch96):  64%|██████▍   | 32/50 [00:05<00:03,  6.00it/s]
# Batch (Epoch96):  66%|██████▌   | 33/50 [00:05<00:02,  6.08it/s]
# Batch (Epoch96):  68%|██████▊   | 34/50 [00:05<00:02,  6.10it/s]
# Batch (Epoch96):  70%|███████   | 35/50 [00:05<00:02,  6.10it/s]
# Batch (Epoch96):  72%|███████▏  | 36/50 [00:05<00:02,  6.07it/s]
# Batch (Epoch96):  74%|███████▍  | 37/50 [00:06<00:02,  6.05it/s]
# Batch (Epoch96):  76%|███████▌  | 38/50 [00:06<00:01,  6.03it/s]
# Batch (Epoch96):  78%|███████▊  | 39/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch96):  80%|████████  | 40/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch96):  82%|████████▏ | 41/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch96):  84%|████████▍ | 42/50 [00:06<00:01,  6.06it/s]
# Batch (Epoch96):  86%|████████▌ | 43/50 [00:07<00:01,  6.03it/s]
# Batch (Epoch96):  88%|████████▊ | 44/50 [00:07<00:00,  6.04it/s]
# Batch (Epoch96):  90%|█████████ | 45/50 [00:07<00:00,  6.03it/s]
# Batch (Epoch96):  92%|█████████▏| 46/50 [00:07<00:00,  5.91it/s]
# Batch (Epoch96):  94%|█████████▍| 47/50 [00:07<00:00,  6.10it/s]
# Batch (Epoch96):  96%|█████████▌| 48/50 [00:07<00:00,  6.11it/s]
# Batch (Epoch96):  98%|█████████▊| 49/50 [00:08<00:00,  6.13it/s]
# Batch (Epoch96): 100%|██████████| 50/50 [00:08<00:00,  6.06it/s]
# Epochs:  96%|█████████▌| 96/100 [13:08<00:33,  8.27s/it]
# Batch (Epoch97):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch97):   2%|▏         | 1/50 [00:00<00:07,  6.70it/s]
# Batch (Epoch97):   4%|▍         | 2/50 [00:00<00:07,  6.26it/s]
# Batch (Epoch97):   6%|▌         | 3/50 [00:00<00:07,  6.14it/s]
# Batch (Epoch97):   8%|▊         | 4/50 [00:00<00:07,  6.11it/s]
# Batch (Epoch97):  10%|█         | 5/50 [00:00<00:07,  6.11it/s]
# Batch (Epoch97):  12%|█▏        | 6/50 [00:00<00:07,  6.09it/s]
# Batch (Epoch97):  14%|█▍        | 7/50 [00:01<00:07,  6.11it/s]
# Batch (Epoch97):  16%|█▌        | 8/50 [00:01<00:06,  6.08it/s]
# Batch (Epoch97):  18%|█▊        | 9/50 [00:01<00:06,  6.04it/s]
# Batch (Epoch97):  20%|██        | 10/50 [00:01<00:06,  5.95it/s]
# Batch (Epoch97):  22%|██▏       | 11/50 [00:01<00:06,  5.93it/s]
# Batch (Epoch97):  24%|██▍       | 12/50 [00:01<00:06,  5.88it/s]
# Batch (Epoch97):  26%|██▌       | 13/50 [00:02<00:06,  6.07it/s]
# Batch (Epoch97):  28%|██▊       | 14/50 [00:02<00:06,  5.90it/s]
# Batch (Epoch97):  30%|███       | 15/50 [00:02<00:05,  5.88it/s]
# Batch (Epoch97):  32%|███▏      | 16/50 [00:02<00:05,  5.97it/s]
# Batch (Epoch97):  34%|███▍      | 17/50 [00:02<00:05,  5.94it/s]
# Batch (Epoch97):  36%|███▌      | 18/50 [00:02<00:05,  5.94it/s]
# Batch (Epoch97):  38%|███▊      | 19/50 [00:03<00:05,  6.05it/s]
# Batch (Epoch97):  40%|████      | 20/50 [00:03<00:05,  5.89it/s]
# Batch (Epoch97):  42%|████▏     | 21/50 [00:03<00:04,  6.03it/s]
# Batch (Epoch97):  44%|████▍     | 22/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch97):  46%|████▌     | 23/50 [00:03<00:04,  5.95it/s]
# Batch (Epoch97):  48%|████▊     | 24/50 [00:03<00:04,  5.93it/s]
# Batch (Epoch97):  50%|█████     | 25/50 [00:04<00:04,  5.99it/s]
# Batch (Epoch97):  52%|█████▏    | 26/50 [00:04<00:04,  5.98it/s]
# Batch (Epoch97):  54%|█████▍    | 27/50 [00:04<00:03,  6.05it/s]
# Batch (Epoch97):  56%|█████▌    | 28/50 [00:04<00:03,  6.05it/s]
# Batch (Epoch97):  58%|█████▊    | 29/50 [00:04<00:03,  6.00it/s]
# Batch (Epoch97):  60%|██████    | 30/50 [00:04<00:03,  6.16it/s]
# Batch (Epoch97):  62%|██████▏   | 31/50 [00:05<00:03,  6.12it/s]
# Batch (Epoch97):  64%|██████▍   | 32/50 [00:05<00:02,  6.14it/s]
# Batch (Epoch97):  66%|██████▌   | 33/50 [00:05<00:02,  6.05it/s]
# Batch (Epoch97):  68%|██████▊   | 34/50 [00:05<00:02,  6.03it/s]
# Batch (Epoch97):  70%|███████   | 35/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch97):  72%|███████▏  | 36/50 [00:05<00:02,  6.03it/s]
# Batch (Epoch97):  74%|███████▍  | 37/50 [00:06<00:02,  6.03it/s]
# Batch (Epoch97):  76%|███████▌  | 38/50 [00:06<00:02,  5.87it/s]
# Batch (Epoch97):  78%|███████▊  | 39/50 [00:06<00:01,  6.00it/s]
# Batch (Epoch97):  80%|████████  | 40/50 [00:06<00:01,  5.96it/s]
# Batch (Epoch97):  82%|████████▏ | 41/50 [00:06<00:01,  6.12it/s]
# Batch (Epoch97):  84%|████████▍ | 42/50 [00:06<00:01,  6.09it/s]
# Batch (Epoch97):  86%|████████▌ | 43/50 [00:07<00:01,  5.93it/s]
# Batch (Epoch97):  88%|████████▊ | 44/50 [00:07<00:00,  6.04it/s]
# Batch (Epoch97):  90%|█████████ | 45/50 [00:07<00:00,  6.04it/s]
# Batch (Epoch97):  92%|█████████▏| 46/50 [00:07<00:00,  6.05it/s]
# Batch (Epoch97):  94%|█████████▍| 47/50 [00:07<00:00,  6.09it/s]
# Batch (Epoch97):  96%|█████████▌| 48/50 [00:07<00:00,  6.02it/s]
# Batch (Epoch97):  98%|█████████▊| 49/50 [00:08<00:00,  6.13it/s]
# Batch (Epoch97): 100%|██████████| 50/50 [00:08<00:00,  6.02it/s]
# Epochs:  97%|█████████▋| 97/100 [13:16<00:24,  8.29s/it]
# Batch (Epoch98):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch98):   2%|▏         | 1/50 [00:00<00:06,  7.61it/s]
# Batch (Epoch98):   4%|▍         | 2/50 [00:00<00:07,  6.39it/s]
# Batch (Epoch98):   6%|▌         | 3/50 [00:00<00:07,  6.11it/s]
# Batch (Epoch98):   8%|▊         | 4/50 [00:00<00:07,  6.10it/s]
# Batch (Epoch98):  10%|█         | 5/50 [00:00<00:07,  6.12it/s]
# Batch (Epoch98):  12%|█▏        | 6/50 [00:00<00:07,  6.22it/s]
# Batch (Epoch98):  14%|█▍        | 7/50 [00:01<00:07,  6.11it/s]
# Batch (Epoch98):  16%|█▌        | 8/50 [00:01<00:07,  5.95it/s]
# Batch (Epoch98):  18%|█▊        | 9/50 [00:01<00:06,  6.02it/s]
# Batch (Epoch98):  20%|██        | 10/50 [00:01<00:06,  6.21it/s]
# Batch (Epoch98):  22%|██▏       | 11/50 [00:01<00:06,  6.07it/s]
# Batch (Epoch98):  24%|██▍       | 12/50 [00:01<00:06,  6.02it/s]
# Batch (Epoch98):  26%|██▌       | 13/50 [00:02<00:06,  6.13it/s]
# Batch (Epoch98):  28%|██▊       | 14/50 [00:02<00:06,  5.88it/s]
# Batch (Epoch98):  30%|███       | 15/50 [00:02<00:05,  6.03it/s]
# Batch (Epoch98):  32%|███▏      | 16/50 [00:02<00:05,  6.17it/s]
# Batch (Epoch98):  34%|███▍      | 17/50 [00:02<00:05,  6.11it/s]
# Batch (Epoch98):  36%|███▌      | 18/50 [00:02<00:05,  6.18it/s]
# Batch (Epoch98):  38%|███▊      | 19/50 [00:03<00:05,  6.04it/s]
# Batch (Epoch98):  40%|████      | 20/50 [00:03<00:04,  6.10it/s]
# Batch (Epoch98):  42%|████▏     | 21/50 [00:03<00:04,  6.16it/s]
# Batch (Epoch98):  44%|████▍     | 22/50 [00:03<00:04,  6.14it/s]
# Batch (Epoch98):  46%|████▌     | 23/50 [00:03<00:04,  6.13it/s]
# Batch (Epoch98):  48%|████▊     | 24/50 [00:03<00:04,  6.12it/s]
# Batch (Epoch98):  50%|█████     | 25/50 [00:04<00:04,  6.08it/s]
# Batch (Epoch98):  52%|█████▏    | 26/50 [00:04<00:03,  6.06it/s]
# Batch (Epoch98):  54%|█████▍    | 27/50 [00:04<00:03,  6.04it/s]
# Batch (Epoch98):  56%|█████▌    | 28/50 [00:04<00:03,  6.05it/s]
# Batch (Epoch98):  58%|█████▊    | 29/50 [00:04<00:03,  6.01it/s]
# Batch (Epoch98):  60%|██████    | 30/50 [00:04<00:03,  6.12it/s]
# Batch (Epoch98):  62%|██████▏   | 31/50 [00:05<00:03,  6.12it/s]
# Batch (Epoch98):  64%|██████▍   | 32/50 [00:05<00:02,  6.10it/s]
# Batch (Epoch98):  66%|██████▌   | 33/50 [00:05<00:02,  6.05it/s]
# Batch (Epoch98):  68%|██████▊   | 34/50 [00:05<00:02,  6.03it/s]
# Batch (Epoch98):  70%|███████   | 35/50 [00:05<00:02,  6.04it/s]
# Batch (Epoch98):  72%|███████▏  | 36/50 [00:05<00:02,  6.07it/s]
# Batch (Epoch98):  74%|███████▍  | 37/50 [00:06<00:02,  6.08it/s]
# Batch (Epoch98):  76%|███████▌  | 38/50 [00:06<00:01,  6.10it/s]
# Batch (Epoch98):  78%|███████▊  | 39/50 [00:06<00:01,  6.07it/s]
# Batch (Epoch98):  80%|████████  | 40/50 [00:06<00:01,  6.06it/s]
# Batch (Epoch98):  82%|████████▏ | 41/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch98):  84%|████████▍ | 42/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch98):  86%|████████▌ | 43/50 [00:07<00:01,  6.05it/s]
# Batch (Epoch98):  88%|████████▊ | 44/50 [00:07<00:01,  5.99it/s]
# Batch (Epoch98):  90%|█████████ | 45/50 [00:07<00:00,  6.08it/s]
# Batch (Epoch98):  92%|█████████▏| 46/50 [00:07<00:00,  6.08it/s]
# Batch (Epoch98):  94%|█████████▍| 47/50 [00:07<00:00,  6.05it/s]
# Batch (Epoch98):  96%|█████████▌| 48/50 [00:07<00:00,  6.05it/s]
# Batch (Epoch98):  98%|█████████▊| 49/50 [00:08<00:00,  6.03it/s]
# Batch (Epoch98): 100%|██████████| 50/50 [00:08<00:00,  6.08it/s]
# Epochs:  98%|█████████▊| 98/100 [13:25<00:16,  8.27s/it]
# Batch (Epoch99):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch99):   2%|▏         | 1/50 [00:00<00:07,  6.31it/s]
# Batch (Epoch99):   4%|▍         | 2/50 [00:00<00:07,  6.25it/s]
# Batch (Epoch99):   6%|▌         | 3/50 [00:00<00:07,  6.20it/s]
# Batch (Epoch99):   8%|▊         | 4/50 [00:00<00:07,  6.20it/s]
# Batch (Epoch99):  10%|█         | 5/50 [00:00<00:07,  6.14it/s]
# Batch (Epoch99):  12%|█▏        | 6/50 [00:00<00:07,  6.10it/s]
# Batch (Epoch99):  14%|█▍        | 7/50 [00:01<00:07,  6.07it/s]
# Batch (Epoch99):  16%|█▌        | 8/50 [00:01<00:06,  6.10it/s]
# Batch (Epoch99):  18%|█▊        | 9/50 [00:01<00:06,  6.08it/s]
# Batch (Epoch99):  20%|██        | 10/50 [00:01<00:06,  6.14it/s]
# Batch (Epoch99):  22%|██▏       | 11/50 [00:01<00:06,  6.12it/s]
# Batch (Epoch99):  24%|██▍       | 12/50 [00:01<00:06,  6.10it/s]
# Batch (Epoch99):  26%|██▌       | 13/50 [00:02<00:06,  6.10it/s]
# Batch (Epoch99):  28%|██▊       | 14/50 [00:02<00:05,  6.07it/s]
# Batch (Epoch99):  30%|███       | 15/50 [00:02<00:05,  6.06it/s]
# Batch (Epoch99):  32%|███▏      | 16/50 [00:02<00:05,  6.07it/s]
# Batch (Epoch99):  34%|███▍      | 17/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch99):  36%|███▌      | 18/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch99):  38%|███▊      | 19/50 [00:03<00:05,  5.99it/s]
# Batch (Epoch99):  40%|████      | 20/50 [00:03<00:04,  6.13it/s]
# Batch (Epoch99):  42%|████▏     | 21/50 [00:03<00:04,  6.09it/s]
# Batch (Epoch99):  44%|████▍     | 22/50 [00:03<00:04,  6.10it/s]
# Batch (Epoch99):  46%|████▌     | 23/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch99):  48%|████▊     | 24/50 [00:03<00:04,  6.06it/s]
# Batch (Epoch99):  50%|█████     | 25/50 [00:04<00:04,  6.05it/s]
# Batch (Epoch99):  52%|█████▏    | 26/50 [00:04<00:03,  6.06it/s]
# Batch (Epoch99):  54%|█████▍    | 27/50 [00:04<00:03,  6.07it/s]
# Batch (Epoch99):  56%|█████▌    | 28/50 [00:04<00:03,  5.99it/s]
# Batch (Epoch99):  58%|█████▊    | 29/50 [00:04<00:03,  6.00it/s]
# Batch (Epoch99):  60%|██████    | 30/50 [00:04<00:03,  5.88it/s]
# Batch (Epoch99):  62%|██████▏   | 31/50 [00:05<00:03,  6.11it/s]
# Batch (Epoch99):  64%|██████▍   | 32/50 [00:05<00:02,  6.04it/s]
# Batch (Epoch99):  66%|██████▌   | 33/50 [00:05<00:02,  5.96it/s]
# Batch (Epoch99):  68%|██████▊   | 34/50 [00:05<00:02,  6.05it/s]
# Batch (Epoch99):  70%|███████   | 35/50 [00:05<00:02,  5.95it/s]
# Batch (Epoch99):  72%|███████▏  | 36/50 [00:05<00:02,  6.18it/s]
# Batch (Epoch99):  74%|███████▍  | 37/50 [00:06<00:02,  6.00it/s]
# Batch (Epoch99):  76%|███████▌  | 38/50 [00:06<00:01,  6.03it/s]
# Batch (Epoch99):  78%|███████▊  | 39/50 [00:06<00:01,  6.05it/s]
# Batch (Epoch99):  80%|████████  | 40/50 [00:06<00:01,  6.03it/s]
# Batch (Epoch99):  82%|████████▏ | 41/50 [00:06<00:01,  6.16it/s]
# Batch (Epoch99):  84%|████████▍ | 42/50 [00:06<00:01,  6.16it/s]
# Batch (Epoch99):  86%|████████▌ | 43/50 [00:07<00:01,  6.12it/s]
# Batch (Epoch99):  88%|████████▊ | 44/50 [00:07<00:00,  6.11it/s]
# Batch (Epoch99):  90%|█████████ | 45/50 [00:07<00:00,  6.06it/s]
# Batch (Epoch99):  92%|█████████▏| 46/50 [00:07<00:00,  6.07it/s]
# Batch (Epoch99):  94%|█████████▍| 47/50 [00:07<00:00,  6.07it/s]
# Batch (Epoch99):  96%|█████████▌| 48/50 [00:07<00:00,  5.98it/s]
# Batch (Epoch99):  98%|█████████▊| 49/50 [00:08<00:00,  5.94it/s]
# Batch (Epoch99): 100%|██████████| 50/50 [00:08<00:00,  6.07it/s]
# Epochs:  99%|█████████▉| 99/100 [13:33<00:08,  8.26s/it]
# Batch (Epoch100):   0%|          | 0/50 [00:00<?, ?it/s]
# Batch (Epoch100):   2%|▏         | 1/50 [00:00<00:07,  6.50it/s]
# Batch (Epoch100):   4%|▍         | 2/50 [00:00<00:07,  6.49it/s]
# Batch (Epoch100):   6%|▌         | 3/50 [00:00<00:07,  6.33it/s]
# Batch (Epoch100):   8%|▊         | 4/50 [00:00<00:07,  6.21it/s]
# Batch (Epoch100):  10%|█         | 5/50 [00:00<00:07,  6.11it/s]
# Batch (Epoch100):  12%|█▏        | 6/50 [00:00<00:07,  6.03it/s]
# Batch (Epoch100):  14%|█▍        | 7/50 [00:01<00:07,  6.10it/s]
# Batch (Epoch100):  16%|█▌        | 8/50 [00:01<00:06,  6.06it/s]
# Batch (Epoch100):  18%|█▊        | 9/50 [00:01<00:06,  6.12it/s]
# Batch (Epoch100):  20%|██        | 10/50 [00:01<00:06,  6.11it/s]
# Batch (Epoch100):  22%|██▏       | 11/50 [00:01<00:06,  6.10it/s]
# Batch (Epoch100):  24%|██▍       | 12/50 [00:01<00:06,  6.09it/s]
# Batch (Epoch100):  26%|██▌       | 13/50 [00:02<00:06,  6.07it/s]
# Batch (Epoch100):  28%|██▊       | 14/50 [00:02<00:05,  6.03it/s]
# Batch (Epoch100):  30%|███       | 15/50 [00:02<00:05,  6.07it/s]
# Batch (Epoch100):  32%|███▏      | 16/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch100):  34%|███▍      | 17/50 [00:02<00:05,  6.08it/s]
# Batch (Epoch100):  36%|███▌      | 18/50 [00:02<00:05,  6.03it/s]
# Batch (Epoch100):  38%|███▊      | 19/50 [00:03<00:05,  5.99it/s]
# Batch (Epoch100):  40%|████      | 20/50 [00:03<00:04,  6.13it/s]
# Batch (Epoch100):  42%|████▏     | 21/50 [00:03<00:04,  6.17it/s]
# Batch (Epoch100):  44%|████▍     | 22/50 [00:03<00:04,  6.05it/s]
# Batch (Epoch100):  46%|████▌     | 23/50 [00:03<00:04,  6.03it/s]
# Batch (Epoch100):  48%|████▊     | 24/50 [00:03<00:04,  5.87it/s]
# Batch (Epoch100):  50%|█████     | 25/50 [00:04<00:04,  6.05it/s]
# Batch (Epoch100):  52%|█████▏    | 26/50 [00:04<00:03,  6.06it/s]
# Batch (Epoch100):  54%|█████▍    | 27/50 [00:04<00:03,  5.97it/s]
# Batch (Epoch100):  56%|█████▌    | 28/50 [00:04<00:03,  6.15it/s]
# Batch (Epoch100):  58%|█████▊    | 29/50 [00:04<00:03,  6.13it/s]
# Batch (Epoch100):  60%|██████    | 30/50 [00:04<00:03,  6.12it/s]
# Batch (Epoch100):  62%|██████▏   | 31/50 [00:05<00:03,  6.04it/s]
# Batch (Epoch100):  64%|██████▍   | 32/50 [00:05<00:02,  6.05it/s]
# Batch (Epoch100):  66%|██████▌   | 33/50 [00:05<00:02,  6.09it/s]
# Batch (Epoch100):  68%|██████▊   | 34/50 [00:05<00:02,  5.94it/s]
# Batch (Epoch100):  70%|███████   | 35/50 [00:05<00:02,  6.02it/s]
# Batch (Epoch100):  72%|███████▏  | 36/50 [00:05<00:02,  6.20it/s]
# Batch (Epoch100):  74%|███████▍  | 37/50 [00:06<00:02,  6.24it/s]
# Batch (Epoch100):  76%|███████▌  | 38/50 [00:06<00:01,  6.17it/s]
# Batch (Epoch100):  78%|███████▊  | 39/50 [00:06<00:01,  6.06it/s]
# Batch (Epoch100):  80%|████████  | 40/50 [00:06<00:01,  6.11it/s]
# Batch (Epoch100):  82%|████████▏ | 41/50 [00:06<00:01,  6.00it/s]
# Batch (Epoch100):  84%|████████▍ | 42/50 [00:06<00:01,  6.12it/s]
# Batch (Epoch100):  86%|████████▌ | 43/50 [00:07<00:01,  6.09it/s]
# Batch (Epoch100):  88%|████████▊ | 44/50 [00:07<00:00,  6.18it/s]
# Batch (Epoch100):  90%|█████████ | 45/50 [00:07<00:00,  6.23it/s]
# Batch (Epoch100):  92%|█████████▏| 46/50 [00:07<00:00,  6.22it/s]
# Batch (Epoch100):  94%|█████████▍| 47/50 [00:07<00:00,  6.20it/s]
# Batch (Epoch100):  96%|█████████▌| 48/50 [00:07<00:00,  6.17it/s]
# Batch (Epoch100):  98%|█████████▊| 49/50 [00:08<00:00,  6.17it/s]
# Batch (Epoch100): 100%|██████████| 50/50 [00:08<00:00,  6.09it/s]
# Epochs: 100%|██████████| 100/100 [13:41<00:00,  8.22s/it]

# %%
def moving_avg(a, n = 10):
  temp = np.cumsum(a, dtype = float)
  temp[n:] = temp[n:] - temp[:-n]
  return temp[n - 1:] / n

moving_avg_loss = moving_avg(loss_values, 10)

plt.figure(figsize=(10,5))
plt.title("Training loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(loss_values, label='Loss')
plt.plot(range(len(moving_avg_loss)), moving_avg_loss, label='Moving Average Loss')
plt.legend()
plt.show()

# %%
model.save_pretrained('/content/drive/MyDrive/BERT Models/BERT Supervised/model')
tokenizer.save_pretrained('/content/drive/MyDrive/BERT Models/BERT Supervised/tokenizer')
# Out:
# ('/content/drive/MyDrive/BERT Models/BERT Supervised/tokenizer/tokenizer_config.json',
#  '/content/drive/MyDrive/BERT Models/BERT Supervised/tokenizer/special_tokens_map.json',
#  '/content/drive/MyDrive/BERT Models/BERT Supervised/tokenizer/vocab.txt',
#  '/content/drive/MyDrive/BERT Models/BERT Supervised/tokenizer/added_tokens.json',
#  '/content/drive/MyDrive/BERT Models/BERT Supervised/tokenizer/tokenizer.json')

# %%
model_dir = '/content/drive/MyDrive/BERT Models/BERT Supervised/model'
tokenizer_dir = '/content/drive/MyDrive/BERT Models/BERT Supervised/tokenizer'
model = DistilBertForSequenceClassification.from_pretrained(model_dir)
tokenizer = DistilBertTokenizerFast.from_pretrained(tokenizer_dir)

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, log_loss
from sklearn import metrics

testData = pd.read_csv('/content/drive/MyDrive/BERT Models/Dataset/unbiasedDataTest.csv')
texts = list(testData['sentence'])

inputs = tokenizer(texts, padding = "max_length", truncation = True, max_length = 128, return_tensors = 'pt')

with torch.no_grad():
  logits = model(**inputs).logits

probs = torch.nn.functional.softmax(logits, dim = -1)

predicted_labels = torch.argmax(probs, dim = -1)
confidence_scores = torch.max(probs, dim=-1)[0]

true_labels = list(testData['label'])

accuracy = accuracy_score(true_labels, predicted_labels.tolist())
f1 = f1_score(true_labels, predicted_labels.tolist())
recall = recall_score(true_labels, predicted_labels.tolist())
precision = precision_score(true_labels, predicted_labels.tolist())
conf_matrix = confusion_matrix(true_labels, predicted_labels.tolist())
matrix = metrics.ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels = ['Slang', 'No Slang'])
probs_np = probs.detach().cpu().numpy()
logloss = log_loss(true_labels, probs_np)

for i, text in enumerate(texts):
  prediction = 'Slang' if predicted_labels[i].item() == 1 else 'No Slang'
  is_correct = "Correct" if predicted_labels[i].item() == true_labels[i] else "Incorrect"
  print(f"Text: {text}")
  print(f"Predicted label: {'Slang' if predicted_labels[i].item() == 1 else 'No Slang'}")
  print(f"Prediction is: {is_correct}")
  print(f"Confidence score: {confidence_scores[i].item()}")
  print("\n")
# Out:
# Text: I guess it started with Legos, then it really got out of hand the first time I put a PC together.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9998241066932678
#
#
# Text: I'm craving some ice cream. Let's go get some.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999639987945557
#
#
# Text: Re-enact the Warriors book series lol Ruin ecosystem :P
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.6739909648895264
#
#
# Text: Uhmmmm..... Idk.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999593496322632
#
#
# Text: I had a gaming rig before, and all I ever did when I got bored was find a PC game to play and only play maybe 20 percent of it.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9976758360862732
#
#
# Text: I think they're more expensive since they're a collab between Adidas and UNDFTD, hence rarer.
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.8502593636512756
#
#
# Text: I have the S9 too by the way, and I really like it!
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999643564224243
#
#
# Text: And can sleep for 12h or something.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999349117279053
#
#
# Text: Good idea! I could use a sweet treat.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9706628322601318
#
#
# Text: If you are taking public transport, spending 20 mins a day on the app can be useful.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9996486902236938
#
#
# Text: It’s 5:49pm and I’m laying on my couch watching Criminal Minds.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999697208404541
#
#
# Text: I'm starving. Let's grab a bite to eat.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999685287475586
#
#
# Text: Got a 32gb version of newest one.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9108547568321228
#
#
# Text: I'm 40 and I've given up a long time ago caring about some internet rando attacking me.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999642372131348
#
#
# Text: Trivia/ game party with some crummy prizes for the winners.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999576807022095
#
#
# Text: Let's grab a cup of coffee and catch up.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999586343765259
#
#
# Text: Awww, you're too adorable.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9762682914733887
#
#
# Text: I feel you. It's been a long day.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9999237060546875
#
#
# Text: Hey OP, please don't name call people.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.999966025352478
#
#
# Text: You know, I've never thought about just polishing a pinky or something to see if anyone even notices.
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.9991777539253235
#
#
# Text: I'm exhausted. Let's call it a night.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999704360961914
#
#
# Text: Wtf is that meant to mean?
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9996360540390015
#
#
# Text: Focus on what you're good at and screw everything else.
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.9997478127479553
#
#
# Text: I totally agree. Goodnight!
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999654293060303
#
#
# Text: yeah but the story for Baby wasnt as good as HF's imo.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999734163284302
#
#
# Text: October means it's time to dig out my winter coat and ankle boots.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9778649806976318
#
#
# Text: Slang and Ebonics eventually end up normal and then looking back you'll be wondering why people spoke that way.
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.6656104326248169
#
#
# Text: I'm planning on going back to Japan in Feb. to visit family and watch the dogsledding race in Wakkanai.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9855740666389465
#
#
# Text: Adrenaline was pumping v high.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999681711196899
#
#
# Text: I can't believe how fast this year is flying by.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999690055847168
#
#
# Text: forward today, huh
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.9999607801437378
#
#
# Text: I think that can be difficult at times, especially because I've been conditioned to treat learning as a means to an end (e.g.
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.9999483823776245
#
#
# Text: I ended up making friends in grad school, though.
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.9950196743011475
#
#
# Text: Just as vile to me lol
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9953765869140625
#
#
# Text: I don't think I'll be lucky enough to find a girl who wants to do that though lol
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999517202377319
#
#
# Text: Still love a good pbj!
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.9999421834945679
#
#
# Text: Congrats is definitely the correct response.
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.9999698400497437
#
#
# Text: I'm so stoked about the party tonight!
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999730587005615
#
#
# Text: Let's have a movie marathon at my place.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999715089797974
#
#
# Text: Things like meat and cheese are quite calorific, try some low calorie alternatives.
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.9999696016311646
#
#
# Text: I'm so excited for the weekend getaway.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999711513519287
#
#
# Text: You should get some rest. Sweet dreams!
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9999570846557617
#
#
# Text: I’m not trying to be a dick, but, don’t you feel shame?
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999593496322632
#
#
# Text: I don’t think I’ve ever seen a meme either??
# Predicted label: No Slang
# Prediction is: Incorrect
# Confidence score: 0.9942775368690491
#
#
# Text: You'll be a bit grumpy about it for a while, but the feelings do pass.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9956041574478149
#
#
# Text: I'm game. The open road awaits us.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999613761901855
#
#
# Text: I even splurged to make it pink because I thought it was cute.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999152421951294
#
#
# Text: Like tilting game cartridges: You ain't reached last ditch until you've done this.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9992493987083435
#
#
# Text: Surprising my BF
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9939269423484802
#
#
# Text: I'm up for that. It'll be refreshing.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999685287475586
#
#
# Text: But yeah you can also just delete if you don’t care about any of that.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999377727508545
#
#
# Text: What tattoos do you have that I might identify?
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999758005142212
#
#
# Text: This you just let it sit there.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999703168869019
#
#
# Text: Ignorance and oblivious persistence do not equal racism.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999608993530273
#
#
# Text: Does anyone else get bothered by workplace passive aggressiveness?
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9998157620429993
#
#
# Text: I couldn't tell you a specific city that would work best for you, but I'm sure there's one that would fit the bill.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999723434448242
#
#
# Text: I really hope it isn't as hard as you say for kids to prosper in foster care over there.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999701976776123
#
#
# Text: I had a job interview and am awaiting a response on monday so I am excited.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9549183249473572
#
#
# Text: It's like my applications disappear into a void.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9999399185180664
#
#
# Text: I always feel like I'm annoying.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.6745670437812805
#
#
# Text: My problem is when I find something I like, I get stuck on it and listen to it over and over and over again.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9998399019241333
#
#
# Text: *  You have to do everything.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999700784683228
#
#
# Text: Just enjoy my presence, think I’m an ok person
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9998026490211487
#
#
# Text: Now, all of us (even me) look and feel better because of it, which again prompts him to keep going.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9998568296432495
#
#
# Text: Nobody knew just how far it was going to go so I kept trading shorts the whole time.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9994787573814392
#
#
# Text: Have a rare Friday night off!
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.999794065952301
#
#
# Text: You played relationship on hard mode and still managed to outlast a lot of couples.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9997833371162415
#
#
# Text: Well whatever works for you but I'd like to take the time to say that there are people out there who won't take you for granted.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999717473983765
#
#
# Text: I read something about Elon Musk making some submarine to help out?
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.7391711473464966
#
#
# Text: My teacher said maybe Finance, if you could come up with a trading/investing strategy, tho that's really hard.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9999667406082153
#
#
# Text: It's getting great reviews. Let's watch it together.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9999692440032959
#
#
# Text: Congrats on making it that long!
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9952860474586487
#
#
# Text: That's a wonderful mindset to have.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999709129333496
#
#
# Text: I know, we've all had a really rough time but it just seems to just be one thing after another for him.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.966955840587616
#
#
# Text: (Please don’t call me lazy.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9993853569030762
#
#
# Text: And enjoy the way he or she grows up.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999680519104004
#
#
# Text: All of these things considered, it would seem arrogant for one to go around talking about how smart they are.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999701976776123
#
#
# Text: I’m a very  polite person  and when I’m uncomfortable, I get even more polite.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999709129333496
#
#
# Text: Ever heard of BirdCat?
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.999940037727356
#
#
# Text: Ironically, stomach cells are destroyed no matter what the diet due to strong digestive acids.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9998897314071655
#
#
# Text: Kyle had been looking for my dad his whole life and was stoked when he finally found him.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.7202672362327576
#
#
# Text: Go for your daughter, not for the other women there.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999707937240601
#
#
# Text: Sure, that sounds like fun.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9994997978210449
#
#
# Text: I don’t care too much about kids bullying over a name.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999676942825317
#
#
# Text: By the way, tea is favorite beverage #1!
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.8828518986701965
#
#
# Text: Is there some sort of an exception because I see faces that somehow resemble or relate to people I know?
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999704360961914
#
#
# Text: And if I take on scuba diving, I am getting the open water course so that package pretty much includes everything.
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.9615126848220825
#
#
# Text: Ok traveling the world is cool and all but I don't think staycations can be beat.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9993535876274109
#
#
# Text: Please do not hate me.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999302625656128
#
#
# Text: Doesn't have to be from comics either or animes.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999516010284424
#
#
# Text: Other than that, I enjoy reading and playing music.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.999956488609314
#
#
# Text: I don't mind doing grunt work or getting messy.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999568462371826
#
#
# Text: You won't believe what happened. It's crazy!
# Predicted label: Slang
# Prediction is: Incorrect
# Confidence score: 0.999934196472168
#
#
# Text: where they can meet new people.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.999968409538269
#
#
# Text: I’m a bit of a scattered guy, pretty heady and such.
# Predicted label: Slang
# Prediction is: Correct
# Confidence score: 0.9999716281890869
#
#
# Text: We would go see Prince there since he had concerts, and it was his hometown.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9998468160629272
#
#
# Text: >What is your most used app on your phone?
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999427795410156
#
#
# Text: But I’m talking about 1% man in good looks, it must he really something.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999325275421143
#
#
# Text: That college age is prime cool for them.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9999754428863525
#
#
# Text: and I wish I had that kind of mom.
# Predicted label: No Slang
# Prediction is: Correct
# Confidence score: 0.9997032284736633

# %%
print(f"Accuracy: {accuracy*100:0.3f}%")
print(f"F1-score: {f1*100:0.3f}%")
print(f"Recall: {recall*100:0.3f}%")
print(f"Precision: {precision*100:0.3f}%")
matrix.plot()
print(f"Log-loss: {logloss}")
plt.show()
# Out:
# Accuracy: 75.000%
# F1-score: 73.684%
# Recall: 76.087%
# Precision: 71.429%
# Log-loss: 1.831158224492543

# %%
labels = data2['label']

# Count occurrences of '0' and '1' labels
label_counts = labels.value_counts()

# Create a bar graph
plt.bar(label_counts.index, label_counts.values)
plt.xlabel('Label')
plt.ylabel('Occurrences')
plt.title('Occurrences of Non-Slang and Slang Labels')
plt.xticks(label_counts.index, ['Non-Slang', 'Slang'])
plt.show()
